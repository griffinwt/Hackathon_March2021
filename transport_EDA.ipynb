# %%
import pandas as pd

# %% [markdown]
# I'd like to write a function which will take in a dataframe of applie mobility data and convert it to each date on a single row and individual columns for each of the 3 categories (walking, transit, driving). I'll use the German data to create it and then generalize to the other country information that we received in a similar format.

# %%
ger = pd.read_excel('./data/Transportation/apple_mobility_Germany.xlsx')

# %%
ger.head() #preview
# Out:
#     Value        Date Super Region              Sub Region   Unit  \
# 0   81.14  2021-01-24  GLOBAL DATA  NORTH RHINE-WESTPHALIA  INDEX
# 1  127.55  2020-08-07  GLOBAL DATA  NORTH RHINE-WESTPHALIA  INDEX
# 2   88.19  2021-01-25  GLOBAL DATA  NORTH RHINE-WESTPHALIA  INDEX
# 3  135.66  2020-08-06  GLOBAL DATA  NORTH RHINE-WESTPHALIA  INDEX
# 4   83.67  2021-01-22  GLOBAL DATA  NORTH RHINE-WESTPHALIA  INDEX
#
#   Geography Type       Source            Sub-Sector Frequency  Region  \
# 0           CITY  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  AACHEN
# 1           CITY  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  AACHEN
# 2           CITY  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  AACHEN
# 3           CITY  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  AACHEN
# 4           CITY  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  AACHEN
#
#    Country Transportation Type
# 0  GERMANY             WALKING
# 1  GERMANY             WALKING
# 2  GERMANY             WALKING
# 3  GERMANY             WALKING
# 4  GERMANY             WALKING

# %%
ger['Geography Type'].value_counts()
# Out:
# CITY          20090
# SUB-REGION    15216
# Name: Geography Type, dtype: int64

# %%
ger['Sub Region'].value_counts()
# Out:
# NORTH RHINE-WESTPHALIA    6150
# BADEN-W++RTTEMBERG        3280
# BAVARIA                   2870
# SAXONY                    1640
# HESSE                     1640
# LOWER SAXONY              1230
# BREMEN (STATE)             820
# Name: Sub Region, dtype: int64

# %%
ger['Region'].value_counts()
# Out:
# BAVARIA                   1234
# LOWER SAXONY              1234
# RHINELAND-PALATINATE      1234
# NORTH RHINE-WESTPHALIA    1234
# BADEN-W++RTTEMBERG        1234
# BRANDENBURG               1234
# SCHLESWIG-HOLSTEIN        1234
# HESSE                     1234
# SAXONY                    1234
# BERLIN                    1230
# DUSSELDORF                1230
# HANNOVER                  1230
# COLOGNE                   1230
# STUTTGART                 1230
# MANNHEIM                  1230
# HAMBURG                   1230
# NUREMBERG                 1230
# BOCHUM - DORTMUND         1230
# BREMEN (STATE)             822
# SAXONY-ANHALT              822
# THURINGIA                  822
# SAARLAND                   822
# MECKLENBURG-VORPOMMERN     822
# AUGSBURG                   820
# KARLSRUHE                  820
# M+¦NCHENGLADBACH           820
# DRESDEN                    820
# MUNICH                     820
# M++NSTER                   820
# LEIPZIG                    820
# AACHEN                     820
# FRANKFURT                  820
# BREMEN                     820
# WIESBADEN                  820
# Name: Region, dtype: int64

# %%
ger.isnull().sum()
# Out:
# Value                      0
# Date                       0
# Super Region               0
# Sub Region             17676
# Unit                       0
# Geography Type             0
# Source                     0
# Sub-Sector                 0
# Frequency                  0
# Region                     0
# Country                    0
# Transportation Type        0
# dtype: int64

# %% [markdown]
# I'll have to divide into regions since sub-region has so many nulls that I can't reasonably impute.
#
# Altogether I'd like to have a 3 columns for each region in the dataframe similar to this:
#
# | Date | Apple-(country)-(region)-transit | Apple-(country)-(region)-walking | Apple-(country)-(region)-driving |
#
# The country signifier doesn't matter NOW but it will matter when we join this dataframe with other countries' mobility data.

# %%
country = ger['Country'][0]

# %%
types = list(dict(ger['Transportation Type'].value_counts()).keys())

# %%
regions = list(dict(ger['Region'].value_counts()).keys())

# %%
ger[(ger['Country']==country)&
    (ger['Region']==regions[0])&
    (ger['Transportation Type']==types[0])  
]['Value'].copy()
# Out:
# 21766     63.98
# 21767    167.52
# 21768     67.65
# 21769    166.75
# 21770     71.01
#           ...
# 22173     96.92
# 22174    172.48
# 22175    158.09
# 22176    147.82
# 22177    135.92
# Name: Value, Length: 412, dtype: float64

# %%
ger['test_column'] = ger[(ger['Country']==country)&
    (ger['Region']==regions[0])&
    (ger['Transportation Type']==types[0])  
]['Value'].copy() #test

# %%
ger[['Date', 'test_column']].notnull().sum()
# Out:
# Date           35306
# test_column      412
# dtype: int64

# %%
ger[ger['test_column'].notnull()]
# Out:
#         Value        Date Super Region Sub Region   Unit Geography Type  \
# 21766   63.98  2021-01-24  GLOBAL DATA        NaN  INDEX     SUB-REGION
# 21767  167.52  2020-08-07  GLOBAL DATA        NaN  INDEX     SUB-REGION
# 21768   67.65  2021-01-25  GLOBAL DATA        NaN  INDEX     SUB-REGION
# 21769  166.75  2020-08-06  GLOBAL DATA        NaN  INDEX     SUB-REGION
# 21770   71.01  2021-01-22  GLOBAL DATA        NaN  INDEX     SUB-REGION
# ...       ...         ...          ...        ...    ...            ...
# 22173   96.92  2020-08-30  GLOBAL DATA        NaN  INDEX     SUB-REGION
# 22174  172.48  2020-09-04  GLOBAL DATA        NaN  INDEX     SUB-REGION
# 22175  158.09  2020-09-03  GLOBAL DATA        NaN  INDEX     SUB-REGION
# 22176  147.82  2020-09-02  GLOBAL DATA        NaN  INDEX     SUB-REGION
# 22177  135.92  2020-09-01  GLOBAL DATA        NaN  INDEX     SUB-REGION
#
#             Source            Sub-Sector Frequency   Region  Country  \
# 21766  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  BAVARIA  GERMANY
# 21767  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  BAVARIA  GERMANY
# 21768  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  BAVARIA  GERMANY
# 21769  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  BAVARIA  GERMANY
# 21770  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  BAVARIA  GERMANY
# ...            ...                   ...       ...      ...      ...
# 22173  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  BAVARIA  GERMANY
# 22174  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  BAVARIA  GERMANY
# 22175  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  BAVARIA  GERMANY
# 22176  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  BAVARIA  GERMANY
# 22177  APPLE, INC.  APPLE MOBILITY INDEX     DAILY  BAVARIA  GERMANY
#
#       Transportation Type  test_column
# 21766             WALKING        63.98
# 21767             WALKING       167.52
# 21768             WALKING        67.65
# 21769             WALKING       166.75
# 21770             WALKING        71.01
# ...                   ...          ...
# 22173             WALKING        96.92
# 22174             WALKING       172.48
# 22175             WALKING       158.09
# 22176             WALKING       147.82
# 22177             WALKING       135.92
#
# [412 rows x 13 columns]

# %%
ger.shape
# Out:
# (35306, 13)

# %%
def transmogrify(some_df):
    country = some_df['Country'][0] #each df is already limited to a single country
    types = list(dict(some_df['Transportation Type'].value_counts()).keys()) #between 1 and 3 depending on data size
    regions = list(dict(some_df['Region'].value_counts()).keys()) #list of all regions
    #print(country, types, regions[:5]) #preview
    #new_cols = []
    for transport in types:
        for region in regions:
            #new_cols.append((f'apple_{country}_{region}_{transport}')) #collect each new column name
            some_df[f'apple_{country}_{region}_{transport}'] = some_df[
                (some_df['Country'] == country)&
                (some_df['Region'] == region)&
                (some_df['Transportation Type'] == transport)
            ]['Value'] #create a new column of values from that country + region + type and name it accordingly
    return some_df#, new_cols

# %%
new_ger, cols = transmogrify(ger)

# %%
new_ger[cols].isnull().sum()
# Out:
# apple_GERMANY_BAVARIA_WALKING                   34894
# apple_GERMANY_LOWER SAXONY_WALKING              34894
# apple_GERMANY_RHINELAND-PALATINATE_WALKING      34894
# apple_GERMANY_NORTH RHINE-WESTPHALIA_WALKING    34894
# apple_GERMANY_BADEN-W++RTTEMBERG_WALKING        34894
#                                                 ...
# apple_GERMANY_LEIPZIG_TRANSIT                   35306
# apple_GERMANY_AACHEN_TRANSIT                    35306
# apple_GERMANY_FRANKFURT_TRANSIT                 35306
# apple_GERMANY_BREMEN_TRANSIT                    35306
# apple_GERMANY_WIESBADEN_TRANSIT                 35306
# Length: 102, dtype: int64

# %%
print(
ger.shape,
new_ger.shape)
# Out:
# (35306, 115) (35306, 115)

# %%
usa_w = pd.read_excel('./data/Transportation/apple_mobility_US_Walking.xlsx')
usa_d = pd.read_excel('./data/Transportation/apple_mobility_US_Driving.xlsx')
usa_t = pd.read_excel('./data/Transportation/apple_mobility_US_Transit.xlsx')

# %%
usa_w.head() #preview
# Out:
#     Value        Date            Sub-Sector Super Region Frequency    Region  \
# 0   82.56  2021-01-24  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY  ILLINOIS
# 1  185.41  2020-08-07  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY  ILLINOIS
# 2   78.86  2021-01-25  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY  ILLINOIS
# 3  152.63  2020-08-06  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY  ILLINOIS
# 4  108.20  2021-01-22  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY  ILLINOIS
#
#          Country   Unit Geography Type Transportation Type       Source
# 0  UNITED STATES  INDEX     SUB-REGION             WALKING  APPLE, INC.
# 1  UNITED STATES  INDEX     SUB-REGION             WALKING  APPLE, INC.
# 2  UNITED STATES  INDEX     SUB-REGION             WALKING  APPLE, INC.
# 3  UNITED STATES  INDEX     SUB-REGION             WALKING  APPLE, INC.
# 4  UNITED STATES  INDEX     SUB-REGION             WALKING  APPLE, INC.

# %%
usa_w = transmogrify(usa_w)

# %%
usa_w
# Out:
#         Value        Date            Sub-Sector Super Region Frequency  \
# 0       82.56  2021-01-24  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY
# 1      185.41  2020-08-07  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY
# 2       78.86  2021-01-25  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY
# 3      152.63  2020-08-06  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY
# 4      108.20  2021-01-22  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY
# ...       ...         ...                   ...          ...       ...
# 21007  211.33  2020-08-30  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY
# 21008  277.22  2020-09-04  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY
# 21009  214.72  2020-09-03  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY
# 21010  215.89  2020-09-02  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY
# 21011  222.63  2020-09-01  APPLE MOBILITY INDEX  GLOBAL DATA     DAILY
#
#          Region        Country   Unit Geography Type Transportation Type  ...  \
# 0      ILLINOIS  UNITED STATES  INDEX     SUB-REGION             WALKING  ...
# 1      ILLINOIS  UNITED STATES  INDEX     SUB-REGION             WALKING  ...
# 2      ILLINOIS  UNITED STATES  INDEX     SUB-REGION             WALKING  ...
# 3      ILLINOIS  UNITED STATES  INDEX     SUB-REGION             WALKING  ...
# 4      ILLINOIS  UNITED STATES  INDEX     SUB-REGION             WALKING  ...
# ...         ...            ...    ...            ...                 ...  ...
# 21007  DELAWARE  UNITED STATES  INDEX     SUB-REGION             WALKING  ...
# 21008  DELAWARE  UNITED STATES  INDEX     SUB-REGION             WALKING  ...
# 21009  DELAWARE  UNITED STATES  INDEX     SUB-REGION             WALKING  ...
# 21010  DELAWARE  UNITED STATES  INDEX     SUB-REGION             WALKING  ...
# 21011  DELAWARE  UNITED STATES  INDEX     SUB-REGION             WALKING  ...
#
#       apple_UNITED STATES_TEXAS_WALKING  apple_UNITED STATES_KENTUCKY_WALKING  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
# ...                                 ...                                   ...
# 21007                               NaN                                   NaN
# 21008                               NaN                                   NaN
# 21009                               NaN                                   NaN
# 21010                               NaN                                   NaN
# 21011                               NaN                                   NaN
#
#        apple_UNITED STATES_OKLAHOMA_WALKING  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 21007                                   NaN
# 21008                                   NaN
# 21009                                   NaN
# 21010                                   NaN
# 21011                                   NaN
#
#        apple_UNITED STATES_SOUTH DAKOTA_WALKING  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 21007                                       NaN
# 21008                                       NaN
# 21009                                       NaN
# 21010                                       NaN
# 21011                                       NaN
#
#        apple_UNITED STATES_UTAH_WALKING  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 21007                               NaN
# 21008                               NaN
# 21009                               NaN
# 21010                               NaN
# 21011                               NaN
#
#        apple_UNITED STATES_MINNESOTA_WALKING  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 21007                                    NaN
# 21008                                    NaN
# 21009                                    NaN
# 21010                                    NaN
# 21011                                    NaN
#
#        apple_UNITED STATES_ARIZONA_WALKING  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 21007                                  NaN
# 21008                                  NaN
# 21009                                  NaN
# 21010                                  NaN
# 21011                                  NaN
#
#        apple_UNITED STATES_RHODE ISLAND_WALKING  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 21007                                       NaN
# 21008                                       NaN
# 21009                                       NaN
# 21010                                       NaN
# 21011                                       NaN
#
#        apple_UNITED STATES_MONTANA_WALKING  apple_UNITED STATES_NEVADA_WALKING
# 0                                      NaN                                 NaN
# 1                                      NaN                                 NaN
# 2                                      NaN                                 NaN
# 3                                      NaN                                 NaN
# 4                                      NaN                                 NaN
# ...                                    ...                                 ...
# 21007                                  NaN                                 NaN
# 21008                                  NaN                                 NaN
# 21009                                  NaN                                 NaN
# 21010                                  NaN                                 NaN
# 21011                                  NaN                                 NaN
#
# [21012 rows x 62 columns]

# %%
usa_w.isnull().sum()
# Out:
# Value                                           0
# Date                                            0
# Sub-Sector                                      0
# Super Region                                    0
# Frequency                                       0
#                                             ...
# apple_UNITED STATES_MINNESOTA_WALKING       20600
# apple_UNITED STATES_ARIZONA_WALKING         20600
# apple_UNITED STATES_RHODE ISLAND_WALKING    20600
# apple_UNITED STATES_MONTANA_WALKING         20600
# apple_UNITED STATES_NEVADA_WALKING          20600
# Length: 62, dtype: int64

# %%
usa_w.shape
# Out:
# (21012, 62)
