# %%
# Import quick EDA Module
from data_explorer import quick_explore

# %%
# Identify the dataset
folder_name = 'Financial_Market'
# Explore all CSV data in folder, plot distributions of values and dates
quick_explore(folder = folder_name)
# Out:
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# COMMODITY_PRICES
#
# Group By: Commodity And Exchange
#                                        Value                               \
#                                        count       mean        std    min
# Commodity And Exchange
# BRENT CRUDE OIL (DOLLARS PER BARREL)  1000.0      58.11      13.59   9.12
# ICE BRENT CRUDE OIL FUTURES           7000.0   89967.89  159403.14 -10.91
# NYMEX CRUDE OIL FUTURES               8000.0  109129.56  223475.24 -40.32
# WTI CRUDE OIL (DOLLARS PER BARREL)    1000.0      53.07      11.95 -36.98
#
#
#                                         25%    50%        75%         max
# Commodity And Exchange
# BRENT CRUDE OIL (DOLLARS PER BARREL)  49.96  60.72      67.46       86.07
# ICE BRENT CRUDE OIL FUTURES           45.90  63.90  165883.75   773838.00
# NYMEX CRUDE OIL FUTURES               44.86  56.80    3120.18  1751861.00
# WTI CRUDE OIL (DOLLARS PER BARREL)    47.02  53.80      61.18       77.41
# Group By: Indicator
#                              Value                                             \
#                              count       mean        std       min        25%
# Indicator
# CHANGE                      2000.0       0.44       2.00    -10.91      -0.02
# HIGH                        2000.0      56.79      12.42     13.69      48.78
# LAST                        1000.0      53.16      11.65    -13.10      47.02
# LOW                         2000.0      55.04      12.84    -40.32      47.48
# OPEN                        2000.0      55.94      12.58    -14.00      48.18
# PREV# DAY OPEN INTEREST     1000.0  370389.01  146024.44  45762.00  257368.50
# PREVIOUS DAY OPEN INTEREST  1000.0  332852.61  161934.96  13044.00  211090.25
# PRICE IN USD                2000.0      55.59      13.04    -36.98      47.82
# SETTLE                      2000.0      55.92      12.69    -37.63      48.14
# VOLUME                      2000.0  399534.33  239350.98  12250.00  230037.25
#
#
#                                   50%        75%         max
# Indicator
# CHANGE                           0.38       0.91       55.90
# HIGH                            57.73      65.52       86.74
# LAST                            53.98      61.34       76.22
# LOW                             56.24      63.90       84.31
# OPEN                            57.00      64.71       85.99
# PREV# DAY OPEN INTEREST     381845.00  488223.75   676659.00
# PREVIOUS DAY OPEN INTEREST  366624.00  447840.25   642781.00
# PRICE IN USD                    56.76      64.63       86.07
# SETTLE                          56.94      64.70       86.29
# VOLUME                      322942.50  572894.75  1751861.00
# {'Sub-Sector': 'COMMODITY PRICES',
#  'Super Region': 'GLOBAL DATA',
#  'Frequency': 'DAILY',
#  'Source': 'COMMODITY EXCHANGE'}
#           Value       Date       Commodity And Exchange  \
# 0      393834.0 2020-08-07      NYMEX CRUDE OIL FUTURES
# 1      865736.0 2018-03-07      NYMEX CRUDE OIL FUTURES
# 2      345299.0 2021-01-25      NYMEX CRUDE OIL FUTURES
# 3      353417.0 2020-08-06      NYMEX CRUDE OIL FUTURES
# 4      626407.0 2018-03-06      NYMEX CRUDE OIL FUTURES
# ...         ...        ...                          ...
# 16995  465881.0 2019-07-05  ICE BRENT CRUDE OIL FUTURES
# 16996  463509.0 2019-07-08  ICE BRENT CRUDE OIL FUTURES
# 16997  295191.0 2018-07-20  ICE BRENT CRUDE OIL FUTURES
# 16998  444816.0 2019-07-09  ICE BRENT CRUDE OIL FUTURES
# 16999  535856.0 2017-07-31  ICE BRENT CRUDE OIL FUTURES
#
#                      Indicator
# 0                       VOLUME
# 1                       VOLUME
# 2                       VOLUME
# 3                       VOLUME
# 4                       VOLUME
# ...                        ...
# 16995  PREV# DAY OPEN INTEREST
# 16996  PREV# DAY OPEN INTEREST
# 16997  PREV# DAY OPEN INTEREST
# 16998  PREV# DAY OPEN INTEREST
# 16999  PREV# DAY OPEN INTEREST
#
# [17000 rows x 4 columns]
# Value Distribution:
# count    1.700000e+04
# mean     8.840723e+04
# std      1.873058e+05
# min     -4.032000e+01
# 25%      4.581000e+01
# 50%      5.943000e+01
# 75%      7.757500e+01
# max      1.751861e+06
# Name: Value, dtype: float64
# Date Distribution:
# count                   17000
# unique                   1101
# top       2019-11-13 00:00:00
# freq                       17
# first     2016-11-22 00:00:00
# last      2021-02-26 00:00:00
# Name: Date, dtype: object
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# FRED_STOCK_MARKET_INDICATORS&INDEX
#
# Group By: Description
#                                    Value                               \
#                                    count      mean      std       min
# Description
# DOW JONES COMPOSITE AVERAGE       1000.0   8503.30   781.65   6100.31
# DOW JONES INDUSTRIAL AVERAGE      1000.0  25528.28  2550.52  18591.93
# DOW JONES TRANSPORTATION AVERAGE  1000.0  10360.32  1095.28   6703.63
# DOW JONES UTILITY AVERAGE         1000.0    774.83    69.06    610.89
# S&P 500                           1000.0   2900.91   367.66   2237.40
#
#
#                                        25%       50%       75%       max
# Description
# DOW JONES COMPOSITE AVERAGE        7998.02   8484.04   8957.91  10547.40
# DOW JONES INDUSTRIAL AVERAGE      24101.29  25581.57  27002.94  31961.86
# DOW JONES TRANSPORTATION AVERAGE   9673.54  10430.84  10919.05  13630.55
# DOW JONES UTILITY AVERAGE           720.86    758.92    830.46    960.89
# S&P 500                            2650.39   2833.84   3098.38   3934.83
# {'Sub-Sector': 'STOCK MARKET INDICATORS & INDEX',
#  'Super Region': 'UNITED STATES',
#  'Time Level': 'DAILY',
#  'Category 2': 'FINANCIAL INDICATORS',
#  'Seasonal Adjustment': 'NOT SEASONALLY ADJUSTED',
#  'Unit': 'INDEX',
#  'Source': 'FEDERAL RESERVE ECONOMIC DATA-FRED'}
#          Value       Date                       Description
# 0       843.23 2020-08-07         DOW JONES UTILITY AVERAGE
# 1       664.80 2018-03-07         DOW JONES UTILITY AVERAGE
# 2       872.17 2021-01-25         DOW JONES UTILITY AVERAGE
# 3       828.87 2020-08-06         DOW JONES UTILITY AVERAGE
# 4       669.68 2018-03-06         DOW JONES UTILITY AVERAGE
# ...        ...        ...                               ...
# 4995  10485.02 2019-07-05  DOW JONES TRANSPORTATION AVERAGE
# 4996  10416.13 2019-07-08  DOW JONES TRANSPORTATION AVERAGE
# 4997  10741.50 2018-07-20  DOW JONES TRANSPORTATION AVERAGE
# 4998  10339.01 2019-07-09  DOW JONES TRANSPORTATION AVERAGE
# 4999   9182.78 2017-07-31  DOW JONES TRANSPORTATION AVERAGE
#
# [5000 rows x 3 columns]
# Value Distribution:
# count     5000.000000
# mean      9613.526282
# std       8795.180847
# min        610.890000
# 25%       2650.387500
# 50%       8394.125000
# 75%      10919.055000
# max      31961.860000
# Name: Value, dtype: float64
# Date Distribution:
# count                    5000
# unique                   1000
# top       2019-04-24 00:00:00
# freq                        5
# first     2017-03-24 00:00:00
# last      2021-02-26 00:00:00
# Name: Date, dtype: object
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# NYSE_CLOSING_PRICE
#
# Group By: Ticker
#          Value
#          count    mean    std    min     25%     50%     75%     max
# Ticker
# BP      1000.0   35.37   8.57  14.90   30.53   38.22   41.73   47.79
# COP     1000.0   54.03  11.92  24.39   44.40   54.60   64.94   79.89
# CVX     1000.0  109.21  15.49  53.63  103.09  114.75  120.29  133.60
# MPC     1000.0   55.79  14.59  16.61   47.67   55.98   65.04   86.39
# MRO     1000.0   13.12   5.04   3.18   10.29   13.60   16.42   23.99
# OXY     1000.0   51.15  23.04   8.88   37.49   60.19   67.47   86.48
# PSX     1000.0   89.43  18.36  42.32   77.50   92.03  102.10  123.34
# PXD     1000.0  143.05  32.15  59.15  126.28  144.54  169.57  212.31
# VLO     1000.0   79.10  19.88  32.97   65.12   79.49   92.00  124.44
# XOM     1000.0   68.84  16.22  31.47   59.68   76.04   81.21   89.07
# Group By: Stock Name
#                                     Value                                \
#                                     count    mean    std    min     25%
# Stock Name
# BP P.L.C.                          1000.0   35.37   8.57  14.90   30.53
# CHEVRON CORPORATION                1000.0  109.21  15.49  53.63  103.09
# CONOCOPHILLIPS                     1000.0   54.03  11.92  24.39   44.40
# EXXON MOBIL CORPORATION            1000.0   68.84  16.22  31.47   59.68
# MARATHON OIL CORPORATION           1000.0   13.12   5.04   3.18   10.29
# MARATHON PETROLEUM CORPORATION     1000.0   55.79  14.59  16.61   47.67
# OCCIDENTAL PETROLEUM CORPORATION   1000.0   51.15  23.04   8.88   37.49
# PHILLIPS 66                        1000.0   89.43  18.36  42.32   77.50
# PIONEER NATURAL RESOURCES COMPANY  1000.0  143.05  32.15  59.15  126.28
# VALERO ENERGY CORPORATION          1000.0   79.10  19.88  32.97   65.12
#
#
#                                       50%     75%     max
# Stock Name
# BP P.L.C.                           38.22   41.73   47.79
# CHEVRON CORPORATION                114.75  120.29  133.60
# CONOCOPHILLIPS                      54.60   64.94   79.89
# EXXON MOBIL CORPORATION             76.04   81.21   89.07
# MARATHON OIL CORPORATION            13.60   16.42   23.99
# MARATHON PETROLEUM CORPORATION      55.98   65.04   86.39
# OCCIDENTAL PETROLEUM CORPORATION    60.19   67.47   86.48
# PHILLIPS 66                         92.03  102.10  123.34
# PIONEER NATURAL RESOURCES COMPANY  144.54  169.57  212.31
# VALERO ENERGY CORPORATION           79.49   92.00  124.44
# {'Super Region': 'GLOBAL DATA',
#  'Time Level': 'DAILY',
#  'Source': 'WORLDDATA.AI',
#  'Sub-Sector': 'GLOBAL STOCK EXCHANGE DATA',
#  'Stock Attribute': 'CLOSING PRICE',
#  'Currency': 'USD',
#  'Data Provider': 'NEW YORK STOCK EXCHANGE',
#  'Stock Exchange': 'NEW YORK STOCK EXCHANGE - STOCK PRICES',
#  'Location': 'AMERICA-NEW_YORK'}
#        Value       Date Ticker                         Stock Name
# 0      36.67 2020-08-07    MPC     MARATHON PETROLEUM CORPORATION
# 1      67.68 2018-03-07    MPC     MARATHON PETROLEUM CORPORATION
# 2      46.23 2021-01-25    MPC     MARATHON PETROLEUM CORPORATION
# 3      35.73 2020-08-06    MPC     MARATHON PETROLEUM CORPORATION
# 4      67.39 2018-03-06    MPC     MARATHON PETROLEUM CORPORATION
# ...      ...        ...    ...                                ...
# 9995  146.52 2019-07-05    PXD  PIONEER NATURAL RESOURCES COMPANY
# 9996  145.80 2019-07-08    PXD  PIONEER NATURAL RESOURCES COMPANY
# 9997  180.95 2018-07-20    PXD  PIONEER NATURAL RESOURCES COMPANY
# 9998  143.36 2019-07-09    PXD  PIONEER NATURAL RESOURCES COMPANY
# 9999  163.10 2017-07-31    PXD  PIONEER NATURAL RESOURCES COMPANY
#
# [10000 rows x 4 columns]
# Value Distribution:
# count    10000.000000
# mean        69.909951
# std         39.792636
# min          3.180000
# 25%         41.340000
# 50%         66.255000
# 75%         91.582500
# max        212.310000
# Name: Value, dtype: float64
# Date Distribution:
# count                   10000
# unique                   1015
# top       2020-09-01 00:00:00
# freq                       10
# first     2017-02-28 00:00:00
# last      2021-02-25 00:00:00
# Name: Date, dtype: object
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# OECD_INTEREST_RATES
#
# Group By: Region
#                          Value
#                          count   mean    std   min   25%   50%    75%    max
# Region
# CHINA                    183.0   5.38   2.44  1.15  4.03  5.31   6.02  12.06
# EURO AREA(16 COUNTRIES)  240.0   3.83   2.99 -0.33  1.30  3.84   5.09  12.04
# EURO AREA(17 COUNTRIES)  240.0   3.78   3.03 -0.40  1.07  3.83   5.09  12.02
# EURO AREA(19 COUNTRIES)  312.0   5.30   3.95 -0.52  2.13  4.43   8.70  15.22
# INDIA                    248.0   7.53   1.64  3.14  6.50  7.50   8.15  13.69
# RUSSIA                   172.0  12.74  13.50  4.23  7.28  8.51  11.64  98.16
# UNITED STATES            985.0   5.61   3.31  0.11  3.35  5.33   7.46  18.39
# Group By: Indicator
#                                     Value                                      \
#                                     count  mean   std   min   25%   50%   75%
# Indicator
# LONG-TERM INTEREST RATES            589.0  7.42  7.87 -0.05  4.12  6.85  8.74
# LONG-TERM INTEREST RATES FORECAST   581.0  5.73  2.98 -0.01  3.84  5.29  7.74
# SHORT-TERM INTEREST RATES           535.0  5.57  4.84 -0.52  2.38  5.06  7.40
# SHORT-TERM INTEREST RATES FORECAST  675.0  4.99  3.40 -0.40  2.24  5.07  6.82
#
#
#                                       max
# Indicator
# LONG-TERM INTEREST RATES            98.16
# LONG-TERM INTEREST RATES FORECAST   14.85
# SHORT-TERM INTEREST RATES           34.30
# SHORT-TERM INTEREST RATES FORECAST  18.39
# {'Sub-Sector': 'INTEREST RATES',
#  'Super Region': 'GLOBAL DATA',
#  'Measure': 'PERCENT PER ANNUM',
#  'Frequency': 'Q',
#  'Source': 'OECD',
#  'Subject': 'TOTAL'}
#       Value       Date                   Region  \
# 0      1.40 2014-12-31  EURO AREA(16 COUNTRIES)
# 1      9.19 1995-03-31  EURO AREA(16 COUNTRIES)
# 2      4.08 2007-03-31  EURO AREA(16 COUNTRIES)
# 3      3.84 2004-12-31  EURO AREA(16 COUNTRIES)
# 4      9.88 1992-12-31  EURO AREA(16 COUNTRIES)
# ...     ...        ...                      ...
# 2375   4.36 2008-06-30                    CHINA
# 2376   2.32 2001-12-31                    CHINA
# 2377   2.15 2002-03-31                    CHINA
# 2378   4.71 2013-06-30                    CHINA
# 2379   3.33 2007-09-30                    CHINA
#
#                               Indicator
# 0     LONG-TERM INTEREST RATES FORECAST
# 1     LONG-TERM INTEREST RATES FORECAST
# 2     LONG-TERM INTEREST RATES FORECAST
# 3     LONG-TERM INTEREST RATES FORECAST
# 4     LONG-TERM INTEREST RATES FORECAST
# ...                                 ...
# 2375          SHORT-TERM INTEREST RATES
# 2376          SHORT-TERM INTEREST RATES
# 2377          SHORT-TERM INTEREST RATES
# 2378          SHORT-TERM INTEREST RATES
# 2379          SHORT-TERM INTEREST RATES
#
# [2380 rows x 4 columns]
# Value Distribution:
# count    2380.000000
# mean        5.901496
# std         5.182307
# min        -0.520000
# 25%         3.360000
# 50%         5.410000
# 75%         7.860000
# max        98.160000
# Name: Value, dtype: float64
# Date Distribution:
# count                    2380
# unique                    271
# top       2013-06-30 00:00:00
# freq                       18
# first     1953-06-30 00:00:00
# last      2020-12-31 00:00:00
# Name: Date, dtype: object
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# SEC_FILINGS_E&P
#
# Group By: Ticker
#         Value                                                        \
#         count          mean           std           min         25%
# Ticker
# COP     806.0  2.403800e+09  7.000001e+09 -8.448900e+10      263.71
# EOG     765.0  5.896517e+08  1.110523e+09 -6.274900e+09  9813000.00
# MRO     742.0  8.505431e+08  2.492018e+09 -4.957000e+09        0.21
# PXD     747.0  2.077439e+08  4.481744e+08 -1.707226e+09        0.41
#
#
#                  50%           75%           max
# Ticker
# COP     1.264500e+09  3.414750e+09  4.903900e+10
# EOG     2.716330e+08  1.055000e+09  7.253000e+09
# MRO     1.865000e+08  9.960000e+08  2.094500e+10
# PXD     6.643800e+07  3.514640e+08  2.641000e+09
# Group By: Company Name
#                                    Value                              \
#                                    count          mean           std
# Company Name
# CONOCOPHILLIPS                     806.0  2.403800e+09  7.000001e+09
# EOG RESOURCES INC.                 765.0  5.896517e+08  1.110523e+09
# MARATHON OIL CORPORATION           742.0  8.505431e+08  2.492018e+09
# PIONEER NATURAL RESOURCES COMPANY  747.0  2.077439e+08  4.481744e+08
#
#                                                                            \
#                                             min         25%           50%
# Company Name
# CONOCOPHILLIPS                    -8.448900e+10      263.71  1.264500e+09
# EOG RESOURCES INC.                -6.274900e+09  9813000.00  2.716330e+08
# MARATHON OIL CORPORATION          -4.957000e+09        0.21  1.865000e+08
# PIONEER NATURAL RESOURCES COMPANY -1.707226e+09        0.41  6.643800e+07
#
#
#                                             75%           max
# Company Name
# CONOCOPHILLIPS                     3.414750e+09  4.903900e+10
# EOG RESOURCES INC.                 1.055000e+09  7.253000e+09
# MARATHON OIL CORPORATION           9.960000e+08  2.094500e+10
# PIONEER NATURAL RESOURCES COMPANY  3.514640e+08  2.641000e+09
# Group By: Company Website
#                                Value                              \
#                                count          mean           std
# Company Website
# HTTP://WWW.CONOCOPHILLIPS.COM  806.0  2.403800e+09  7.000001e+09
# HTTP://WWW.EOGRESOURCES.COM    765.0  5.896517e+08  1.110523e+09
# HTTP://WWW.MARATHONOIL.COM     742.0  8.505431e+08  2.492018e+09
# HTTP://WWW.PXD.COM             747.0  2.077439e+08  4.481744e+08
#
#                                                                        \
#                                         min         25%           50%
# Company Website
# HTTP://WWW.CONOCOPHILLIPS.COM -8.448900e+10      263.71  1.264500e+09
# HTTP://WWW.EOGRESOURCES.COM   -6.274900e+09  9813000.00  2.716330e+08
# HTTP://WWW.MARATHONOIL.COM    -4.957000e+09        0.21  1.865000e+08
# HTTP://WWW.PXD.COM            -1.707226e+09        0.41  6.643800e+07
#
#
#                                         75%           max
# Company Website
# HTTP://WWW.CONOCOPHILLIPS.COM  3.414750e+09  4.903900e+10
# HTTP://WWW.EOGRESOURCES.COM    1.055000e+09  7.253000e+09
# HTTP://WWW.MARATHONOIL.COM     9.960000e+08  2.094500e+10
# HTTP://WWW.PXD.COM             3.514640e+08  2.641000e+09
# {'Super Region': 'UNITED STATES',
#  'Time Level': 'QUARTER',
#  'Unit': 'USD',
#  'Source': 'COMPANY SEC FILINGS',
#  'Exchange': 'NEW YORK STOCK EXCHANGE',
#  'Sub-Sector': 'FINANCIAL STATEMENT',
#  'Industry Level 2': 'OIL & GAS - E&P',
#  'Industry Level 1': 'ENERGY',
#  'Statement Type': 'INCOME-STATEMENT',
#  'Market Cap': 'GREATER THAN $1BILLION MARKET CAP'}
#              Value       Date Ticker                       Company Name  \
# 0    -2.010000e+08 2014-12-31    MRO           MARATHON OIL CORPORATION
# 1    -2.380000e+08 2016-06-30    MRO           MARATHON OIL CORPORATION
# 2    -2.400000e+07 2016-12-31    MRO           MARATHON OIL CORPORATION
# 3    -4.200000e+08 2015-03-31    MRO           MARATHON OIL CORPORATION
# 4     5.110000e+08 2014-06-30    MRO           MARATHON OIL CORPORATION
# ...            ...        ...    ...                                ...
# 3055 -5.220000e+05 2009-06-30    PXD  PIONEER NATURAL RESOURCES COMPANY
# 3056  1.535200e+07 2010-03-31    PXD  PIONEER NATURAL RESOURCES COMPANY
# 3057  7.000000e-02 2009-12-31    EOG                 EOG RESOURCES INC.
# 3058  7.000000e-02 2009-09-30    EOG                 EOG RESOURCES INC.
# 3059  7.000000e-02 2009-06-30    EOG                 EOG RESOURCES INC.
#
#                   Company Website                  Financial Metric
# 0      HTTP://WWW.MARATHONOIL.COM               EARNINGS BEFORE TAX
# 1      HTTP://WWW.MARATHONOIL.COM               EARNINGS BEFORE TAX
# 2      HTTP://WWW.MARATHONOIL.COM               EARNINGS BEFORE TAX
# 3      HTTP://WWW.MARATHONOIL.COM               EARNINGS BEFORE TAX
# 4      HTTP://WWW.MARATHONOIL.COM               EARNINGS BEFORE TAX
# ...                           ...                               ...
# 3055           HTTP://WWW.PXD.COM  NET INCOME - NON-CONTROLLING INT
# 3056           HTTP://WWW.PXD.COM  NET INCOME - NON-CONTROLLING INT
# 3057  HTTP://WWW.EOGRESOURCES.COM                DIVIDEND PER SHARE
# 3058  HTTP://WWW.EOGRESOURCES.COM                DIVIDEND PER SHARE
# 3059  HTTP://WWW.EOGRESOURCES.COM                DIVIDEND PER SHARE
#
# [3060 rows x 6 columns]
# Value Distribution:
# count    3.060000e+03
# mean     1.037528e+09
# std      3.933789e+09
# min     -8.448900e+10
# 25%      1.390000e+00
# 50%      2.330000e+08
# 75%      1.141650e+09
# max      4.903900e+10
# Name: Value, dtype: float64
# Date Distribution:
# count                    3060
# unique                     48
# top       2009-09-30 00:00:00
# freq                       75
# first     2009-06-30 00:00:00
# last      2020-06-30 00:00:00
# Name: Date, dtype: object
# Financial Metric Distribution:
# count                    3060
# unique                     20
# top       EARNINGS BEFORE TAX
# freq                      182
# Name: Financial Metric, dtype: object
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# SEC_FILINGS_INTEGRATED
#
# Group By: Ticker
#         Value                                                          \
#         count          mean           std           min           25%
# Ticker
# BP       88.0  1.203774e+10  2.315360e+10  2.300000e-01  7.600000e+08
# CVX     783.0  7.995284e+09  1.199803e+10 -1.060000e+10  2.130000e+08
# OXY     738.0  9.849160e+08  1.660020e+09 -6.749000e+09  1.820000e+00
# XOM     776.0  1.375398e+10  2.456051e+10 -4.370600e+10  1.927500e+08
#
#
#                  50%           75%           max
# Ticker
# BP      2.800000e+09  6.713000e+09  7.946800e+10
# CVX     3.638000e+09  1.142300e+10  6.667100e+10
# OXY     4.570000e+08  1.852250e+09  6.789000e+09
# XOM     4.263000e+09  1.279050e+10  1.237120e+11
# Group By: Company Name
#                                   Value                              \
#                                   count          mean           std
# Company Name
# BP P.L.C.                          88.0  1.203774e+10  2.315360e+10
# CHEVRON CORPORATION               783.0  7.995284e+09  1.199803e+10
# EXXON MOBIL CORPORATION           776.0  1.375398e+10  2.456051e+10
# OCCIDENTAL PETROLEUM CORPORATION  738.0  9.849160e+08  1.660020e+09
#
#                                                                             \
#                                            min           25%           50%
# Company Name
# BP P.L.C.                         2.300000e-01  7.600000e+08  2.800000e+09
# CHEVRON CORPORATION              -1.060000e+10  2.130000e+08  3.638000e+09
# EXXON MOBIL CORPORATION          -4.370600e+10  1.927500e+08  4.263000e+09
# OCCIDENTAL PETROLEUM CORPORATION -6.749000e+09  1.820000e+00  4.570000e+08
#
#
#                                            75%           max
# Company Name
# BP P.L.C.                         6.713000e+09  7.946800e+10
# CHEVRON CORPORATION               1.142300e+10  6.667100e+10
# EXXON MOBIL CORPORATION           1.279050e+10  1.237120e+11
# OCCIDENTAL PETROLEUM CORPORATION  1.852250e+09  6.789000e+09
# Group By: Company Website
#                                      Value                              \
#                                      count          mean           std
# Company Website
# HTTP://WWW.BP.COM                     88.0  1.203774e+10  2.315360e+10
# HTTP://WWW.CHEVRON.COM               783.0  7.995284e+09  1.199803e+10
# HTTP://WWW.CORPORATE.EXXONMOBIL.COM  776.0  1.375398e+10  2.456051e+10
# HTTP://WWW.OXY.COM                   738.0  9.849160e+08  1.660020e+09
#
#                                                                                \
#                                               min           25%           50%
# Company Website
# HTTP://WWW.BP.COM                    2.300000e-01  7.600000e+08  2.800000e+09
# HTTP://WWW.CHEVRON.COM              -1.060000e+10  2.130000e+08  3.638000e+09
# HTTP://WWW.CORPORATE.EXXONMOBIL.COM -4.370600e+10  1.927500e+08  4.263000e+09
# HTTP://WWW.OXY.COM                  -6.749000e+09  1.820000e+00  4.570000e+08
#
#
#                                               75%           max
# Company Website
# HTTP://WWW.BP.COM                    6.713000e+09  7.946800e+10
# HTTP://WWW.CHEVRON.COM               1.142300e+10  6.667100e+10
# HTTP://WWW.CORPORATE.EXXONMOBIL.COM  1.279050e+10  1.237120e+11
# HTTP://WWW.OXY.COM                   1.852250e+09  6.789000e+09
# {'Super Region': 'UNITED STATES',
#  'Time Level': 'QUARTER',
#  'Unit': 'USD',
#  'Source': 'COMPANY SEC FILINGS',
#  'Exchange': 'NEW YORK STOCK EXCHANGE',
#  'Sub-Sector': 'FINANCIAL STATEMENT',
#  'Industry Level 2': 'OIL & GAS - INTEGRATED',
#  'Industry Level 1': 'ENERGY',
#  'Statement Type': 'INCOME-STATEMENT',
#  'Market Cap': 'GREATER THAN $1BILLION MARKET CAP'}
#             Value       Date Ticker                      Company Name  \
# 0      68000000.0 2014-12-31    XOM           EXXON MOBIL CORPORATION
# 1      75000000.0 2016-06-30    XOM           EXXON MOBIL CORPORATION
# 2     195000000.0 2016-12-31    XOM           EXXON MOBIL CORPORATION
# 3      88000000.0 2015-03-31    XOM           EXXON MOBIL CORPORATION
# 4      64000000.0 2014-06-30    XOM           EXXON MOBIL CORPORATION
# ...           ...        ...    ...                               ...
# 2380   15000000.0 2009-09-30    CVX               CHEVRON CORPORATION
# 2381   16000000.0 2009-06-30    CVX               CHEVRON CORPORATION
# 2382  229000000.0 2009-12-31    OXY  OCCIDENTAL PETROLEUM CORPORATION
# 2383    2000000.0 2009-09-30    OXY  OCCIDENTAL PETROLEUM CORPORATION
# 2384    2000000.0 2009-06-30    OXY  OCCIDENTAL PETROLEUM CORPORATION
#
#                           Company Website                  Financial Metric
# 0     HTTP://WWW.CORPORATE.EXXONMOBIL.COM                  INTEREST EXPENSE
# 1     HTTP://WWW.CORPORATE.EXXONMOBIL.COM                  INTEREST EXPENSE
# 2     HTTP://WWW.CORPORATE.EXXONMOBIL.COM                  INTEREST EXPENSE
# 3     HTTP://WWW.CORPORATE.EXXONMOBIL.COM                  INTEREST EXPENSE
# 4     HTTP://WWW.CORPORATE.EXXONMOBIL.COM                  INTEREST EXPENSE
# ...                                   ...                               ...
# 2380               HTTP://WWW.CHEVRON.COM  NET INCOME - NON-CONTROLLING INT
# 2381               HTTP://WWW.CHEVRON.COM  NET INCOME - NON-CONTROLLING INT
# 2382                   HTTP://WWW.OXY.COM     NET INCOME - DISCONTINUED OPS
# 2383                   HTTP://WWW.OXY.COM     NET INCOME - DISCONTINUED OPS
# 2384                   HTTP://WWW.OXY.COM     NET INCOME - DISCONTINUED OPS
#
# [2385 rows x 6 columns]
# Value Distribution:
# count    2.385000e+03
# mean     7.848882e+09
# std      1.703882e+10
# min     -4.370600e+10
# 25%      5.200000e+07
# 50%      2.037000e+09
# 75%      7.245000e+09
# max      1.237120e+11
# Name: Value, dtype: float64
# Date Distribution:
# count                    2385
# unique                     46
# top       2018-12-31 00:00:00
# freq                       67
# first     2009-06-30 00:00:00
# last      2020-06-30 00:00:00
# Name: Date, dtype: object
# Financial Metric Distribution:
# count                    2385
# unique                     20
# top       EARNINGS BEFORE TAX
# freq                      141
# Name: Financial Metric, dtype: object
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# SEC_FILINGS_REF&MARK_O&G_SERVICES
#
# Group By: Ticker
#         Value                                                         \
#         count          mean           std           min          25%
# Ticker
# BHGE    195.0  7.268051e+08  1.479372e+09 -3.570000e+08         0.18
# MPC     693.0  2.900532e+09  6.730466e+09 -1.215500e+10         4.09
# PSX     665.0  4.324334e+09  1.024589e+10 -3.436000e+09  73000000.00
# VLO     776.0  3.498125e+09  8.349960e+09 -1.480100e+10         2.63
#
#
#                 50%           75%           max
# Ticker
# BHGE     82000000.0  6.680000e+08  6.265000e+09
# MPC     445000000.0  1.388000e+09  3.354700e+10
# PSX     736000000.0  1.654000e+09  5.343000e+10
# VLO     578500000.0  1.413500e+09  3.613700e+10
# Group By: Company Name
#                                    Value                              \
#                                    count          mean           std
# Company Name
# BAKER HUGHES A GE COMPANY CLASS A  195.0  7.268051e+08  1.479372e+09
# MARATHON PETROLEUM CORPORATION     693.0  2.900532e+09  6.730466e+09
# PHILLIPS 66                        665.0  4.324334e+09  1.024589e+10
# VALERO ENERGY CORPORATION          776.0  3.498125e+09  8.349960e+09
#
#                                                                            \
#                                             min          25%          50%
# Company Name
# BAKER HUGHES A GE COMPANY CLASS A -3.570000e+08         0.18   82000000.0
# MARATHON PETROLEUM CORPORATION    -1.215500e+10         4.09  445000000.0
# PHILLIPS 66                       -3.436000e+09  73000000.00  736000000.0
# VALERO ENERGY CORPORATION         -1.480100e+10         2.63  578500000.0
#
#
#                                             75%           max
# Company Name
# BAKER HUGHES A GE COMPANY CLASS A  6.680000e+08  6.265000e+09
# MARATHON PETROLEUM CORPORATION     1.388000e+09  3.354700e+10
# PHILLIPS 66                        1.654000e+09  5.343000e+10
# VALERO ENERGY CORPORATION          1.413500e+09  3.613700e+10
# Group By: Industry Level 2
#                                    Value                              \
#                                    count          mean           std
# Industry Level 2
# OIL & GAS - REFINING & MARKETING  2134.0  3.561526e+09  8.545948e+09
# OIL & GAS - SERVICES               195.0  7.268051e+08  1.479372e+09
#
#                                                                          \
#                                            min         25%          50%
# Industry Level 2
# OIL & GAS - REFINING & MARKETING -1.480100e+10  5000000.00  591500000.0
# OIL & GAS - SERVICES             -3.570000e+08        0.18   82000000.0
#
#
#                                            75%           max
# Industry Level 2
# OIL & GAS - REFINING & MARKETING  1.494500e+09  5.343000e+10
# OIL & GAS - SERVICES              6.680000e+08  6.265000e+09
# Group By: Company Website
#                                   Value                              \
#                                   count          mean           std
# Company Website
# HTTP://WWW.MARATHONPETROLEUM.COM  693.0  2.900532e+09  6.730466e+09
# HTTP://WWW.PHILLIPS66.COM         665.0  4.324334e+09  1.024589e+10
# HTTP://WWW.VALERO.COM             776.0  3.498125e+09  8.349960e+09
# HTTPS://WWW.BHGE.COM              195.0  7.268051e+08  1.479372e+09
#
#                                                                           \
#                                            min          25%          50%
# Company Website
# HTTP://WWW.MARATHONPETROLEUM.COM -1.215500e+10         4.09  445000000.0
# HTTP://WWW.PHILLIPS66.COM        -3.436000e+09  73000000.00  736000000.0
# HTTP://WWW.VALERO.COM            -1.480100e+10         2.63  578500000.0
# HTTPS://WWW.BHGE.COM             -3.570000e+08         0.18   82000000.0
#
#
#                                            75%           max
# Company Website
# HTTP://WWW.MARATHONPETROLEUM.COM  1.388000e+09  3.354700e+10
# HTTP://WWW.PHILLIPS66.COM         1.654000e+09  5.343000e+10
# HTTP://WWW.VALERO.COM             1.413500e+09  3.613700e+10
# HTTPS://WWW.BHGE.COM              6.680000e+08  6.265000e+09
# {'Super Region': 'UNITED STATES',
#  'Time Level': 'QUARTER',
#  'Unit': 'USD',
#  'Source': 'COMPANY SEC FILINGS',
#  'Exchange': 'NEW YORK STOCK EXCHANGE',
#  'Sub-Sector': 'FINANCIAL STATEMENT',
#  'Industry Level 1': 'ENERGY',
#  'Statement Type': 'INCOME-STATEMENT',
#  'Market Cap': 'GREATER THAN $1BILLION MARKET CAP'}
#              Value       Date Ticker               Company Name  \
# 0     1.674000e+09 2014-12-31    PSX                PHILLIPS 66
# 1     1.089000e+09 2016-06-30    PSX                PHILLIPS 66
# 2     4.560000e+08 2016-12-31    PSX                PHILLIPS 66
# 3     1.654000e+09 2015-03-31    PSX                PHILLIPS 66
# 4     1.687000e+09 2014-06-30    PSX                PHILLIPS 66
# ...            ...        ...    ...                        ...
# 2324  1.000000e+06 2011-03-31    PSX                PHILLIPS 66
# 2325  1.000000e+06 2011-06-30    PSX                PHILLIPS 66
# 2326 -4.040000e+08 2009-12-31    VLO  VALERO ENERGY CORPORATION
# 2327  2.860000e+08 2009-09-30    VLO  VALERO ENERGY CORPORATION
# 2328  6.300000e+07 2009-06-30    VLO  VALERO ENERGY CORPORATION
#
#                       Industry Level 2            Company Website  \
# 0     OIL & GAS - REFINING & MARKETING  HTTP://WWW.PHILLIPS66.COM
# 1     OIL & GAS - REFINING & MARKETING  HTTP://WWW.PHILLIPS66.COM
# 2     OIL & GAS - REFINING & MARKETING  HTTP://WWW.PHILLIPS66.COM
# 3     OIL & GAS - REFINING & MARKETING  HTTP://WWW.PHILLIPS66.COM
# 4     OIL & GAS - REFINING & MARKETING  HTTP://WWW.PHILLIPS66.COM
# ...                                ...                        ...
# 2324  OIL & GAS - REFINING & MARKETING  HTTP://WWW.PHILLIPS66.COM
# 2325  OIL & GAS - REFINING & MARKETING  HTTP://WWW.PHILLIPS66.COM
# 2326  OIL & GAS - REFINING & MARKETING      HTTP://WWW.VALERO.COM
# 2327  OIL & GAS - REFINING & MARKETING      HTTP://WWW.VALERO.COM
# 2328  OIL & GAS - REFINING & MARKETING      HTTP://WWW.VALERO.COM
#
#                       Financial Metric
# 0                               EBITDA
# 1                               EBITDA
# 2                               EBITDA
# 3                               EBITDA
# 4                               EBITDA
# ...                                ...
# 2324  NET INCOME - NON-CONTROLLING INT
# 2325  NET INCOME - NON-CONTROLLING INT
# 2326     NET INCOME - DISCONTINUED OPS
# 2327     NET INCOME - DISCONTINUED OPS
# 2328     NET INCOME - DISCONTINUED OPS
#
# [2329 rows x 7 columns]
# Value Distribution:
# count    2.329000e+03
# mean     3.324183e+09
# std      8.228904e+09
# min     -1.480100e+10
# 25%      3.000000e+06
# 50%      5.240000e+08
# 75%      1.424000e+09
# max      5.343000e+10
# Name: Value, dtype: float64
# Date Distribution:
# count                    2329
# unique                     46
# top       2018-12-31 00:00:00
# freq                       69
# first     2009-06-30 00:00:00
# last      2020-09-30 00:00:00
# Name: Date, dtype: object
# Financial Metric Distribution:
# count                    2329
# unique                     20
# top       EARNINGS BEFORE TAX
# freq                      139
# Name: Financial Metric, dtype: object
