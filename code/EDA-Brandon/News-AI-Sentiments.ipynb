# %%
# Import quick EDA Module
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np
import seaborn as sns

# %%
# # Initial Auto-Explore
# folder_name = 'News_AI_Sentiments'
# # Explore all CSV data in folder, plot distributions of values and dates
# quick_explore(folder = folder_name)

# %%
# # Explicit function to load data with Auto-Preprocessing for early EDA
# folder_name = 'Sample_dataset'
# directory = '../data/News_AI_Sentiments/'
# for filename in os.listdir(directory):
#     
#     filepath = os.path.join(directory, filename)
#     
#     if filename.endswith('.csv'):
#         raw_df = pd.read_csv(filepath, infer_datetime_format = True)
#         neg_index = 4
# 
#     elif filename.endswith('.xlsx'):
#         raw_df = pd.read_excel(filepath, infer_datetime_format = True)
#         neg_index = 5
#         
#     else:
#         continue
#         
#     print()
#     print('--------------'*8)
#     print('--------------'*8)
#     print(filename[:-neg_index].upper())
#     print()
#     
#     df, redund_dict = preprocess_data(raw_df)

# %%
# Check if any item in ONE is also in TWO
def FIND_OVERLAP(one, two):
    category_1 = one
    category_2 = two
    overlap = [source for source in category_1 if source in category_2]
    print(f'{len(overlap)} sources found in overlap')
    return overlap

# %%
# overlap = [source for source in global_news if source in financial_news]
# len(overlap)
# 
# global_not_financial = [source for source in global_news if source not in financial_news]
# len(global_not_financial)
# 
# financial_not_global = [source for source in financial_news if source not in global_news]
# len(financial_not_global)
# 
# financial_not_finoil = [source for source in financial_news if source not in financial_oil]
# len(financial_not_finoil)
# 
# finoil_not_financial = [source for source in financial_oil if source not in financial_news]
# len(finoil_not_financial)

# %%
#  From https://mediabiasfactcheck.com/fake-news/
#  https://stackoverflow.com/questions/640001/how-can-i-remove-text-within-parentheses-with-a-regex
# 
# questionable_media = pd.DataFrame(questionable_sources, columns=['questionable_sources'])
# for index, media in enumerate(questionable_media.questionable_sources):
#     questionable_media.questionable_sources[index] = re.sub(r'\([^)]*\)', '', media).upper().strip()
# questionable_media.to_csv(r'./questionable_news_sources.csv', index = False)

# %%
# # Global News Sources
# media_df = pd.DataFrame(global_news, columns=['news'])
# media_df['financial_news'] = 0
# media_df
# 
# # Global-FINANCIAL News Sources
# media1_df = pd.DataFrame(financial_news, columns=['news'])
# media1_df['financial_news'] = 1
# media1_df
# 
# # Merge the two labelled groups of news-media sources
# media_df = pd.concat([media_df,media1_df], ignore_index=True, axis=0)
# media_df.sort_values(by='news', ignore_index = True)
# #media_df.to_csv(r'./news_media.csv', index = False)

# %%
# Media Bias Fact Check
fact_reporting = {'Very High':5,
                  'High':4,
                  'Mostly Factual':3,
                  'Mixed':2,
                  'Lov':1,
                  'Very Low':0}

bias = {'Party2': 2, # right
        'Party2 Center': 1,
        'Least Biased': 0,
        'Party1 Center':-1,
        'Party1': -2 } # left

# Press Freedom Index, World Press Freedom Rank, for countries

# %%
# # From https://mediabiasfactcheck.com/fake-news/
# # https://stackoverflow.com/questions/640001/how-can-i-remove-text-within-parentheses-with-a-regex
# left_df = pd.DataFrame(left_biased, columns=['news'])
# for index, media in enumerate(left_df.news):
#     left_df.news[index] = re.sub(r'\([^)]*\)', '', media).upper().strip()
# left_df['bias'] = -2
# left_df.to_csv(r'./left_bias.csv', index = False)
# left_df
# 
# # From https://mediabiasfactcheck.com/fake-news/
# # https://stackoverflow.com/questions/640001/how-can-i-remove-text-within-parentheses-with-a-regex
# left_center_df = pd.DataFrame(left_center_bias, columns=['news'])
# for index, media in enumerate(left_center_df.news):
#     left_center_df.news[index] = re.sub(r'\([^)]*\)', '', media).upper().strip()
# left_center_df['bias'] = -1
# left_center_df.to_csv(r'./left_center_bias.csv', index = False)
# left_center_df
# 
# # From https://mediabiasfactcheck.com/fake-news/
# # https://stackoverflow.com/questions/640001/how-can-i-remove-text-within-parentheses-with-a-regex
# right_center_df = pd.DataFrame(right_center_bias, columns=['news'])
# for index, media in enumerate(right_center_df.news):
#     right_center_df.news[index] = re.sub(r'\([^)]*\)', '', media).upper().strip()
# right_center_df['bias'] = 1
# right_center_df.to_csv(r'./right_center_bias.csv', index = False)
# right_center_df
# 
# # From https://mediabiasfactcheck.com/fake-news/
# # https://stackoverflow.com/questions/640001/how-can-i-remove-text-within-parentheses-with-a-regex
# right_df = pd.DataFrame(right_biased, columns=['news'])
# for index, media in enumerate(right_df.news):
#     right_df.news[index] = re.sub(r'\([^)]*\)', '', media).upper().strip()
# right_df['bias'] = 2
# right_df.to_csv(r'./right_bias.csv', index = False)
# right_df
# 
# # From https://mediabiasfactcheck.com/fake-news/
# # https://stackoverflow.com/questions/640001/how-can-i-remove-text-within-parentheses-with-a-regex
# least_df = pd.DataFrame(least_biased, columns=['news'])
# for index, media in enumerate(least_df.news):
#     least_df.news[index] = re.sub(r'\([^)]*\)', '', media).upper().strip()
# least_df['bias'] = 0
# least_df.to_csv(r'./least_bias.csv', index = False)
# least_df
# 
# # Merge all of the bias ranked media sources together
# bias_df = pd.concat([left_df, left_center_df, least_df, right_center_df, right_df],
#                     ignore_index=True,
#                     axis=0)
# bias_df.sort_values(by='news',
#                     ignore_index = True,
#                     inplace = True)
# #bias_df.to_csv(r'./bias.csv', index = False)

# %%
global_news = pd.read_csv('./news_media.csv')
global_news
# Out:
#                           news  financial_news  bias
# 0                24/7 WALL ST.               1   0.0
# 1          ABA BANKING JOURNAL               1   NaN
# 2                          ABC               0   1.0
# 3                     ABC NEWS               0  -1.0
# 4    ALTERNATIVE ENERGY STOCKS               1   NaN
# ..                         ...             ...   ...
# 461                 WUXI DAILY               0   NaN
# 462              YAHOO FINANCE               1   NaN
# 463       YANGTSE EVENING POST               0   NaN
# 464  ZACKS INVESTMENT RESEARCH               1   NaN
# 465            ZHONGSHAN DAILY               0   NaN
#
# [466 rows x 3 columns]

# %%
a = global_news.loc[global_news['news'] == 'CHRON', 'bias']
a
# Out:
# 54   NaN
# Name: bias, dtype: float64

# %%
global_news.loc[global_news['news'] == 'CHRON', 'bias'] = -1

# %%
global_news.loc[global_news['news'] == 'CHRON', 'bias']
# Out:
# 54   -1.0
# Name: bias, dtype: float64

# %%
bias_df = pd.read_csv('./bias.csv')
bias_df
# Out:
#                   news  bias
# 0         1010 WINS AM     0
# 1         12 NEWS KPNX     0
# 2      1440 NEWSLETTER     0
# 3           1600 DAILY    -1
# 4        24/7 WALL ST.     0
# ...                ...   ...
# 1915  YOUR BLACK WORLD    -2
# 1916       YOUTH RADIO    -1
# 1917        Z MAGAZINE    -2
# 1918             ZDNET     0
# 1919  ZEBRA FACT CHECK     1
#
# [1920 rows x 2 columns]

# %%
bias_df.loc[bias_df['news'] == 'HOUSTON CHRONICLE', 'bias']
# Out:
# 735   -1
# Name: bias, dtype: int64

# %%
#global_news[global_news['news']=='CHRON'].index
global_news.loc[global_news['news'] == 'CHRON', 'bias'] = bias_df.loc[bias_df['news'] == 'HOUSTON CHRONICLE', 'bias']

# %%
search = 'HOUSTON CHRONICLE' 
row = bias_df.loc[bias_df.isin([search]).any(axis=1)].index
global_news.loc[global_news['news'] == 'CHRON', 'bias'] = row

# %%
FIND_OVERLAP(global_news, bias_df)
# Out:
# 2 sources found in overlap
# ['news', 'bias']

# %%
FIND_OVERLAP(bias_df, global_news)
# Out:
# 2 sources found in overlap
# ['news', 'bias']

# %%
dummy_merge = global_news.merge(bias_df, how = 'left', on = 'news')

# %%
dummy_merge.isnull().sum()
# Out:
# news                0
# financial_news      0
# bias_x            311
# bias_y            353
# dtype: int64

# %%
dummy_merge
# Out:
#                           news  financial_news  bias_x  bias_y
# 0                24/7 WALL ST.               1     0.0     0.0
# 1          ABA BANKING JOURNAL               1     NaN     NaN
# 2                          ABC               0     1.0     1.0
# 3                     ABC NEWS               0    -1.0    -1.0
# 4    ALTERNATIVE ENERGY STOCKS               1     NaN     NaN
# ..                         ...             ...     ...     ...
# 461                 WUXI DAILY               0     NaN     NaN
# 462              YAHOO FINANCE               1     NaN     NaN
# 463       YANGTSE EVENING POST               0     NaN     NaN
# 464  ZACKS INVESTMENT RESEARCH               1     NaN     NaN
# 465            ZHONGSHAN DAILY               0     NaN     NaN
#
# [466 rows x 4 columns]

# %%
bias_df.news[1800:1860];

# %%
# %who DataFrame
# Out:
# bias_df	 dummy_merge	 global_news

# %%
# %whos
# Out:
# Variable         Type          Data/Info
# ----------------------------------------
# FIND_OVERLAP     function      <function FIND_OVERLAP at 0x000001A6718D70D0>
# a                Series        54   NaN\nName: bias, dtype: float64
# bias             dict          n=5
# bias_df          DataFrame                       news  b<...>\n[1920 rows x 2 columns]
# dummy_merge      DataFrame                              <...>n\n[466 rows x 4 columns]
# fact_reporting   dict          n=6
# global_news      DataFrame                              <...>n\n[466 rows x 3 columns]
# pd               module        <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt              module        <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# re               module        <module 're' from 'C:\\Us<...>\\anaconda3\\lib\\re.py'>
# row              Int64Index    Int64Index([735], dtype='int64')
# search           str           HOUSTON CHRONICLE

# %%
bias_df
# Out:
#                   news  bias
# 0         1010 WINS AM     0
# 1         12 NEWS KPNX     0
# 2      1440 NEWSLETTER     0
# 3           1600 DAILY    -1
# 4        24/7 WALL ST.     0
# ...                ...   ...
# 1915  YOUR BLACK WORLD    -2
# 1916       YOUTH RADIO    -1
# 1917        Z MAGAZINE    -2
# 1918             ZDNET     0
# 1919  ZEBRA FACT CHECK     1
#
# [1920 rows x 2 columns]

# %%
matches = []
non_matches = []
non_match = 0
multimatch = 0
for gn in global_news.news:
    count = 0
    for bias in bias_df.news:
        f = bias.find(gn)
        if f != -1:
            if count == 0:
                first_match = gn
                fm = bias
                # Stop if an exact match is found on 1st try
                if (gn == bias) | (gn[4:] == bias) | (gn == bias[4:]):
                    count += 1
                    break
            elif count == 1:
                # Perfect match found after one submatch found
                if (gn == bias) | (gn[4:] == bias) | (gn == bias[4:]):
                    first_match = gn
                    fm = bias
                    break
                print()
                print('MULTI-MATCH!')
                print(f'Global: {first_match}, Bias: {fm}')
                print(f'Global: {gn}, Bias: {bias}')
            elif count > 1:
                # Perfect match found after 2+ submatches were found
                if (gn == bias) | (gn[4:] == bias) | (gn == bias[4:]):
                    first_match = gn
                    fm = bias
                    count = 1
                    break
                print(f'Global: {gn}, Bias: {bias}')
            count += 1
        elif f == -1:
            continue
    if count == 0:
        non_matches.append(gn)
        non_match += 1
    if count == 1:
        try:
            value = bias_df.loc[bias_df.news == first_match, 'bias'].values[0]
            print()
            print('ONE PERFECT MATCH!')
            print(f'Global: {first_match}, Bias: {fm}')
            matches.append((first_match, value))
        except IndexError:
            try:
                value = bias_df.loc[bias_df.news == first_match[4:], 'bias'].values[0]
                print()
                print('ONE PERFECT MATCH!')
                print(f'Global: {first_match}, Bias: {fm}')
                matches.append((first_match, value))
            except IndexError:
                try:
                    value = bias_df.loc[bias_df.news == ('THE '+first_match), 'bias'].values[0]
                    print()
                    print('ONE PERFECT MATCH!')
                    print(f'Global: {first_match}, Bias: {fm}')
                    matches.append((first_match, value))
                except IndexError:
                        print('!!!WARNING ------------------INEXACT MATCH FOUND----------------- WARNING!!!')
                        print(f'Substring: {first_match}, Bias: {fm}')
                        continue
    elif count > 1:
        print(f'Number of false matches: {count - 1}')
        print()
        multimatch += 1
display(f'Single Matches: {len(matches)}')
display(f'Multi Matches: {multimatch}')
display(f'Non-Matches: {len(non_matches)}')
display(f'Total news sources: {len(global_news)}')
# Out:
# ONE PERFECT MATCH!
# Global: 24/7 WALL ST., Bias: 24/7 WALL ST.
#
# ONE PERFECT MATCH!
# Global: ABC, Bias: ABC
#
# ONE PERFECT MATCH!
# Global: ABC NEWS, Bias: ABC NEWS
#
# ONE PERFECT MATCH!
# Global: ANCHORAGE DAILY NEWS, Bias: ANCHORAGE DAILY NEWS
#
# ONE PERFECT MATCH!
# Global: ARIZONA DAILY STAR, Bias: ARIZONA DAILY STAR
#
# ONE PERFECT MATCH!
# Global: AUSTIN AMERICAN-STATESMAN, Bias: AUSTIN AMERICAN-STATESMAN
#
# ONE PERFECT MATCH!
# Global: BANGKOK POST, Bias: BANGKOK POST
#
# ONE PERFECT MATCH!
# Global: BANGOR DAILY NEWS, Bias: BANGOR DAILY NEWS
#
# ONE PERFECT MATCH!
# Global: BBC NEWS, Bias: BBC NEWS
#
# ONE PERFECT MATCH!
# Global: BILD, Bias: BILD
#
# ONE PERFECT MATCH!
# Global: BOSTON HERALD, Bias: BOSTON HERALD
#
# ONE PERFECT MATCH!
# Global: BOSTON.COM, Bias: BOSTON.COM
#
# ONE PERFECT MATCH!
# Global: BUENOS AIRES TIMES, Bias: BUENOS AIRES TIMES
#
# ONE PERFECT MATCH!
# Global: BUSINESS INSIDER, Bias: BUSINESS INSIDER
#
# ONE PERFECT MATCH!
# Global: CALGARY HERALD, Bias: CALGARY HERALD
#
# ONE PERFECT MATCH!
# Global: CBS NEWS, Bias: CBS NEWS
#
# ONE PERFECT MATCH!
# Global: CHICAGO SUN-TIMES, Bias: CHICAGO SUN-TIMES
#
# ONE PERFECT MATCH!
# Global: CHICAGO TRIBUNE, Bias: CHICAGO TRIBUNE
#
# MULTI-MATCH!
# Global: CHRON, Bias: BOZEMAN DAILY CHRONICLE
# Global: CHRON, Bias: CHRONICLES MAGAZINE
# Global: CHRON, Bias: DECCAN CHRONICLE
# Global: CHRON, Bias: DEMOCRACY CHRONICLES
# Global: CHRON, Bias: DEMOCRAT AND CHRONICLE
# Global: CHRON, Bias: DENTON RECORD-CHRONICLE
# Global: CHRON, Bias: HOUSTON CHRONICLE
# Global: CHRON, Bias: SAN FRANCISCO CHRONICLE
# Global: CHRON, Bias: THE AUGUSTA CHRONICLE
# Global: CHRON, Bias: THE AUSTIN CHRONICLE
# Global: CHRON, Bias: THE CHRONICLE HERALD
# Global: CHRON, Bias: THE CHRONICLE OF HIGHER EDUCATION
# Global: CHRON, Bias: THE DAILY CHRONICLE
# Global: CHRON, Bias: THE DC CHRONICLE
# Global: CHRON, Bias: THE PALESTINE CHRONICLE
# Number of false matches: 14
#
#
# MULTI-MATCH!
# Global: CITIZEN, Bias: ASHEVILLE CITIZEN-TIMES
# Global: CITIZEN, Bias: CITIZEN CRITICS
# Global: CITIZEN, Bias: CITIZEN FREE PRESS
# Global: CITIZEN, Bias: CITIZEN TRUTH
# Global: CITIZEN, Bias: CITIZENS AGAINST GOVERNMENT WASTE
# Global: CITIZEN, Bias: CITIZENS FOR RESPONSIBILITY AND ETHICS IN WASHINGTON
# Global: CITIZEN, Bias: CITIZENS FOR TAX JUSTICE
# Global: CITIZEN, Bias: CITIZENS UNITED
# Global: CITIZEN, Bias: ENERGY CITIZENS
# Global: CITIZEN, Bias: GLOBAL CITIZEN
# Global: CITIZEN, Bias: ICITIZEN
# Global: CITIZEN, Bias: OTTAWA CITIZEN
# Global: CITIZEN, Bias: PUBLIC CITIZEN
# Global: CITIZEN, Bias: THE AUBURN CITIZEN
#
# ONE PERFECT MATCH!
# Global: CITIZEN, Bias: THE CITIZEN
#
# ONE PERFECT MATCH!
# Global: CNBC, Bias: CNBC
#
# ONE PERFECT MATCH!
# Global: CNET, Bias: CNET
#
# ONE PERFECT MATCH!
# Global: CNN, Bias: CNN
#
# ONE PERFECT MATCH!
# Global: DAILY EXPRESS, Bias: DAILY EXPRESS
#
# ONE PERFECT MATCH!
# Global: DAILY MIRROR, Bias: DAILY MIRROR
#
# MULTI-MATCH!
# Global: DAILY NEWS, Bias: ANCHORAGE DAILY NEWS
# Global: DAILY NEWS, Bias: BANGOR DAILY NEWS
# Global: DAILY NEWS, Bias: DAILY NEWS BIN
# Global: DAILY NEWS, Bias: DAYTON DAILY NEWS
# Global: DAILY NEWS, Bias: DUTCH DAILY NEWS
# Global: DAILY NEWS, Bias: HURRIYET DAILY NEWS
# Global: DAILY NEWS, Bias: LEBANON DAILY NEWS
# Global: DAILY NEWS, Bias: LOS ANGELES DAILY NEWS
# Global: DAILY NEWS, Bias: METROWEST DAILY NEWS
# Global: DAILY NEWS, Bias: MEXICO DAILY NEWS
# Global: DAILY NEWS, Bias: NAPLES DAILY NEWS
# Global: DAILY NEWS, Bias: NEW YORK DAILY NEWS
# Global: DAILY NEWS, Bias: NORFOLK DAILY NEWS
# Global: DAILY NEWS, Bias: NORTHWEST FLORIDA DAILY NEWS
# Global: DAILY NEWS, Bias: PACIFIC DAILY NEWS
# Global: DAILY NEWS, Bias: PALM BEACH DAILY NEWS
# Global: DAILY NEWS, Bias: PENINSULA DAILY NEWS
# Global: DAILY NEWS, Bias: STUDENT DAILY NEWS
#
# ONE PERFECT MATCH!
# Global: DAILY NEWS, Bias: THE DAILY NEWS
#
# MULTI-MATCH!
# Global: DAILY SUN, Bias: ARIZONA DAILY SUN
# Global: DAILY SUN, Bias: LACONIA DAILY SUN
# Number of false matches: 1
#
#
# ONE PERFECT MATCH!
# Global: DAWN, Bias: DAWN
#
# ONE PERFECT MATCH!
# Global: DAYTON DAILY NEWS, Bias: DAYTON DAILY NEWS
#
# ONE PERFECT MATCH!
# Global: DECCAN CHRONICLE, Bias: DECCAN CHRONICLE
#
# ONE PERFECT MATCH!
# Global: DECCAN HERALD, Bias: DECCAN HERALD
#
# ONE PERFECT MATCH!
# Global: DEFENSE NEWS, Bias: DEFENSE NEWS
#
# ONE PERFECT MATCH!
# Global: DETROIT FREE PRESS, Bias: DETROIT FREE PRESS
#
# ONE PERFECT MATCH!
# Global: DIE WELT, Bias: DIE WELT
#
# ONE PERFECT MATCH!
# Global: DIE ZEIT, Bias: DIE ZEIT
#
# ONE PERFECT MATCH!
# Global: EGYPT TODAY, Bias: EGYPT TODAY
# !!!WARNING ------------------INEXACT MATCH FOUND----------------- WARNING!!!
# Substring: ENTREPRENEUR, Bias: ENTREPRENEUR MAGAZINE
#
# ONE PERFECT MATCH!
# Global: FINANCIAL POST, Bias: FINANCIAL POST
#
# ONE PERFECT MATCH!
# Global: FINANCIAL TIMES, Bias: FINANCIAL TIMES
#
# ONE PERFECT MATCH!
# Global: FORBES, Bias: FORBES
#
# ONE PERFECT MATCH!
# Global: FORT WORTH STAR-TELEGRAM, Bias: FORT WORTH STAR-TELEGRAM
# !!!WARNING ------------------INEXACT MATCH FOUND----------------- WARNING!!!
# Substring: FORTUNE, Bias: FORTUNE MAGAZINE
#
# ONE PERFECT MATCH!
# Global: FOX BUSINESS, Bias: FOX BUSINESS
#
# ONE PERFECT MATCH!
# Global: FOX NEWS, Bias: FOX NEWS
#
# ONE PERFECT MATCH!
# Global: HARTFORD COURANT, Bias: HARTFORD COURANT
#
# ONE PERFECT MATCH!
# Global: HEALTHCARE FINANCE NEWS, Bias: HEALTHCARE FINANCE NEWS
#
# ONE PERFECT MATCH!
# Global: HERALD SUN, Bias: HERALD SUN
#
# ONE PERFECT MATCH!
# Global: HIGH POINT ENTERPRISE, Bias: HIGH POINT ENTERPRISE
#
# ONE PERFECT MATCH!
# Global: INVESTOPEDIA, Bias: INVESTOPEDIA
#
# ONE PERFECT MATCH!
# Global: JAPAN TIMES, Bias: JAPAN TIMES
#
# ONE PERFECT MATCH!
# Global: JAPAN TODAY, Bias: JAPAN TODAY
#
# ONE PERFECT MATCH!
# Global: KYIV POST, Bias: KYIV POST
#
# ONE PERFECT MATCH!
# Global: LA PRESSE, Bias: LA PRESSE
#
# ONE PERFECT MATCH!
# Global: LA REPUBBLICA, Bias: LA REPUBBLICA
#
# ONE PERFECT MATCH!
# Global: LAS VEGAS SUN, Bias: LAS VEGAS SUN
#
# ONE PERFECT MATCH!
# Global: LOS ANGELES DAILY NEWS, Bias: LOS ANGELES DAILY NEWS
#
# ONE PERFECT MATCH!
# Global: MANILA BULLETIN, Bias: MANILA BULLETIN
#
# ONE PERFECT MATCH!
# Global: METRO, Bias: METRO
# !!!WARNING ------------------INEXACT MATCH FOUND----------------- WARNING!!!
# Substring: MINT, Bias: MINT PRESS NEWS
#
# ONE PERFECT MATCH!
# Global: MORNING STAR, Bias: THE MORNING STAR
#
# MULTI-MATCH!
# Global: NATION, Bias: AMNESTY INTERNATIONAL
# Global: NATION, Bias: APTN NATIONAL NEWS
# Global: NATION, Bias: ASIAN NEWS INTERNATIONAL
# Global: NATION, Bias: ASSYRIAN INTERNATIONAL NEWS AGENCY
# Global: NATION, Bias: BELFER CENTER FOR SCIENCE AND INTERNATIONAL AFFAIRS
# Global: NATION, Bias: CARNEGIE ENDOWMENT FOR INTERNATIONAL PEACE
# Global: NATION, Bias: CENTER FOR INTERNATIONAL POLICY
# Global: NATION, Bias: CENTER FOR STRATEGIC AND INTERNATIONAL STUDIES
# Global: NATION, Bias: CENTER FOR THE NATIONAL INTEREST
# Global: NATION, Bias: COUNCIL FOR THE NATIONAL INTEREST
# Global: NATION, Bias: COWGER NATION
# Global: NATION, Bias: DAILY NATION
# Global: NATION, Bias: INTERNATIONAL BUSINESS TIMES
# Global: NATION, Bias: INTERNATIONAL CENTER FOR RESEARCH ON WOMEN
# Global: NATION, Bias: INTERNATIONAL CONSORTIUM OF INVESTIGATIVE JOURNALISTS
# Global: NATION, Bias: INTERNATIONAL CRISIS GROUP
# Global: NATION, Bias: INTERNATIONAL ENERGY AGENCY
# Global: NATION, Bias: INTERNATIONAL ORGANIZATION
# Global: NATION, Bias: INTERNATIONAL PRESS INSTITUTE
# Global: NATION, Bias: INTERNATIONAL RESCUE COMMITTEE
# Global: NATION, Bias: INTERNATIONAL VIEWPOINT
# Global: NATION, Bias: LGBTQ NATION
# Global: NATION, Bias: LIBERTY NATION
# Global: NATION, Bias: LIFE DECISIONS INTERNATIONAL
# Global: NATION, Bias: NATION OF CHANGE
# Global: NATION, Bias: NATIONAL AFFAIRS
# Global: NATION, Bias: NATIONAL ASSOCIATION FOR THE ADVANCEMENT OF COLORED PEOPLE
# Global: NATION, Bias: NATIONAL BUREAU OF ECONOMIC RESEARCH
# Global: NATION, Bias: NATIONAL CENTER FOR PUBLIC POLICY RESEARCH
# Global: NATION, Bias: NATIONAL CENTER FOR TRANSGENDER EQUALITY
# Global: NATION, Bias: NATIONAL CONFERENCE OF STATE LEGISLATURES
# Global: NATION, Bias: NATIONAL FEDERATION OF REPUBLICAN WOMEN
# Global: NATION, Bias: NATIONAL INSTITUTE ON MONEY IN STATE POLITICS
# Global: NATION, Bias: NATIONAL INTEREST
# Global: NATION, Bias: NATIONAL JOURNAL
# Global: NATION, Bias: NATIONAL MONITOR
# Global: NATION, Bias: NATIONAL NEWSWATCH
# Global: NATION, Bias: NATIONAL OBSERVER
# Global: NATION, Bias: NATIONAL POST
# Global: NATION, Bias: NATIONAL REVIEW
# Global: NATION, Bias: NATIONAL YOUTH RIGHT ASSOCIATION
# Global: NATION, Bias: NATIONMASTER
# Global: NATION, Bias: NEW INTERNATIONALIST
#
# ONE PERFECT MATCH!
# Global: NATION, Bias: NEWSNATION
#
# ONE PERFECT MATCH!
# Global: NATIONAL POST, Bias: NATIONAL POST
#
# ONE PERFECT MATCH!
# Global: NATIONAL REVIEW, Bias: NATIONAL REVIEW
#
# ONE PERFECT MATCH!
# Global: NBC NEWS, Bias: NBC NEWS
#
# ONE PERFECT MATCH!
# Global: NEW YORK DAILY NEWS, Bias: NEW YORK DAILY NEWS
#
# ONE PERFECT MATCH!
# Global: NEW YORK POST, Bias: NEW YORK POST
#
# ONE PERFECT MATCH!
# Global: NEWS.COM.AU, Bias: NEWS.COM.AU
#
# ONE PERFECT MATCH!
# Global: NEWS24, Bias: NEWS24
#
# ONE PERFECT MATCH!
# Global: NEWSDAY, Bias: NEWSDAY
#
# ONE PERFECT MATCH!
# Global: NEWSWEEK, Bias: NEWSWEEK
#
# ONE PERFECT MATCH!
# Global: NPR, Bias: NPR
#
# ONE PERFECT MATCH!
# Global: ORLANDO SENTINEL, Bias: ORLANDO SENTINEL
#
# ONE PERFECT MATCH!
# Global: OTTAWA CITIZEN, Bias: OTTAWA CITIZEN
#
# ONE PERFECT MATCH!
# Global: PITTSBURGH POST-GAZETTE, Bias: PITTSBURGH POST-GAZETTE
#
# ONE PERFECT MATCH!
# Global: POLITICO, Bias: POLITICO
#
# ONE PERFECT MATCH!
# Global: REUTERS, Bias: REUTERS
#
# ONE PERFECT MATCH!
# Global: RICHMOND TIMES-DISPATCH, Bias: RICHMOND TIMES-DISPATCH
#
# ONE PERFECT MATCH!
# Global: SALT LAKE TRIBUNE, Bias: SALT LAKE TRIBUNE
#
# ONE PERFECT MATCH!
# Global: SAN FRANCISCO CHRONICLE, Bias: SAN FRANCISCO CHRONICLE
#
# ONE PERFECT MATCH!
# Global: SAN JOSE MERCURY NEWS, Bias: SAN JOSE MERCURY NEWS
#
# ONE PERFECT MATCH!
# Global: SARASOTA HERALD-TRIBUNE, Bias: SARASOTA HERALD-TRIBUNE
#
# ONE PERFECT MATCH!
# Global: SAUDI GAZETTE, Bias: SAUDI GAZETTE
#
# ONE PERFECT MATCH!
# Global: SEATTLE POST-INTELLIGENCER, Bias: SEATTLE POST-INTELLIGENCER
#
# ONE PERFECT MATCH!
# Global: SOUTH FLORIDA SUN-SENTINEL, Bias: SOUTH FLORIDA SUN-SENTINEL
#
# ONE PERFECT MATCH!
# Global: ST. LOUIS POST-DISPATCH, Bias: ST. LOUIS POST-DISPATCH
#
# ONE PERFECT MATCH!
# Global: ST. PAUL PIONEER PRESS, Bias: ST. PAUL PIONEER PRESS
#
# ONE PERFECT MATCH!
# Global: TAMPA BAY TIMES, Bias: TAMPA BAY TIMES
#
# ONE PERFECT MATCH!
# Global: THE ADVERTISER, Bias: THE ADVERTISER
#
# ONE PERFECT MATCH!
# Global: THE ADVOCATE, Bias: THE ADVOCATE
#
# ONE PERFECT MATCH!
# Global: THE AGE, Bias: THE AGE
#
# ONE PERFECT MATCH!
# Global: THE AUSTRALIAN, Bias: THE AUSTRALIAN
#
# ONE PERFECT MATCH!
# Global: THE AUSTRALIAN FINANCIAL REVIEW, Bias: THE AUSTRALIAN FINANCIAL REVIEW
#
# ONE PERFECT MATCH!
# Global: THE COURIER-JOURNAL, Bias: THE COURIER-JOURNAL
#
# ONE PERFECT MATCH!
# Global: THE GLOBE AND MAIL, Bias: THE GLOBE AND MAIL
#
# ONE PERFECT MATCH!
# Global: THE GUARDIAN, Bias: THE GUARDIAN
#
# ONE PERFECT MATCH!
# Global: THE HERALD, Bias: THE HERALD
#
# ONE PERFECT MATCH!
# Global: THE HILL, Bias: THE HILL
#
# ONE PERFECT MATCH!
# Global: THE HINDU, Bias: THE HINDU
#
# ONE PERFECT MATCH!
# Global: THE INDEPENDENT, Bias: THE INDEPENDENT
#
# ONE PERFECT MATCH!
# Global: THE INDIAN EXPRESS, Bias: THE INDIAN EXPRESS
#
# ONE PERFECT MATCH!
# Global: THE JAKARTA POST, Bias: THE JAKARTA POST
#
# ONE PERFECT MATCH!
# Global: THE MOTLEY FOOL, Bias: THE MOTLEY FOOL
#
# MULTI-MATCH!
# Global: THE NATION, Bias: CENTER FOR THE NATIONAL INTEREST
# Global: THE NATION, Bias: COUNCIL FOR THE NATIONAL INTEREST
#
# ONE PERFECT MATCH!
# Global: THE NATION, Bias: THE NATION
#
# ONE PERFECT MATCH!
# Global: THE PALM BEACH POST, Bias: THE PALM BEACH POST
#
# ONE PERFECT MATCH!
# Global: THE PATRIOT-NEWS, Bias: THE PATRIOT-NEWS
#
# ONE PERFECT MATCH!
# Global: THE PLAIN DEALER, Bias: THE PLAIN DEALER
#
# ONE PERFECT MATCH!
# Global: THE POST AND COURIER, Bias: THE POST AND COURIER
#
# ONE PERFECT MATCH!
# Global: THE PRESS-ENTERPRISE, Bias: THE PRESS-ENTERPRISE
#
# ONE PERFECT MATCH!
# Global: THE RECORD, Bias: THE RECORD
#
# ONE PERFECT MATCH!
# Global: THE SENTINEL, Bias: THE SENTINEL
#
# ONE PERFECT MATCH!
# Global: THE SPOKESMAN-REVIEW, Bias: THE SPOKESMAN-REVIEW
#
# ONE PERFECT MATCH!
# Global: THE STANDARD, Bias: THE STANDARD
#
# ONE PERFECT MATCH!
# Global: THE STATE, Bias: THE STATE
#
# ONE PERFECT MATCH!
# Global: THE STRAITS TIMES, Bias: THE STRAITS TIMES
#
# ONE PERFECT MATCH!
# Global: THE SYDNEY MORNING HERALD, Bias: THE SYDNEY MORNING HERALD
#
# ONE PERFECT MATCH!
# Global: THE TENNESSEAN, Bias: THE TENNESSEAN
#
# ONE PERFECT MATCH!
# Global: THE TIMES, Bias: THE TIMES
#
# ONE PERFECT MATCH!
# Global: THE WEST AUSTRALIAN, Bias: THE WEST AUSTRALIAN
# !!!WARNING ------------------INEXACT MATCH FOUND----------------- WARNING!!!
# Substring: TIMES UNION, Bias: FLORIDA TIMES UNION
#
# MULTI-MATCH!
# Global: TODAY, Bias: ALABAMA TODAY
# Global: TODAY, Bias: CHRISTIAN TODAY
# Global: TODAY, Bias: CHRISTIANITY TODAY
# Global: TODAY, Bias: CONSERVATIVE TODAY
# Global: TODAY, Bias: EGYPT TODAY
# Global: TODAY, Bias: INDIA TODAY
# Global: TODAY, Bias: JAPAN TODAY
# Global: TODAY, Bias: LAW ENFORCEMENT TODAY
# Global: TODAY, Bias: MALAYSIA TODAY
# Global: TODAY, Bias: SOOTODAY.COM
# Global: TODAY, Bias: TODAY I FOUND OUT
# Global: TODAY, Bias: TODAY.COM
# !!!WARNING ------------------INEXACT MATCH FOUND----------------- WARNING!!!
# Substring: TODAY, Bias: USA TODAY
#
# ONE PERFECT MATCH!
# Global: TORONTO STAR, Bias: TORONTO STAR
#
# ONE PERFECT MATCH!
# Global: TORONTO SUN, Bias: TORONTO SUN
#
# ONE PERFECT MATCH!
# Global: USA TODAY, Bias: USA TODAY
#
# ONE PERFECT MATCH!
# Global: WINNIPEG FREE PRESS, Bias: WINNIPEG FREE PRESS
#
# MULTI-MATCH!
# Global: WORTH, Bias: FORT WORTH STAR-TELEGRAM
# Global: WORTH, Bias: FORT WORTH WEEKLY
# Global: WORTH, Bias: LEAVENWORTH TIMES
# Global: WORTH, Bias: UPWORTHY
# Number of false matches: 3
# 'Single Matches: 117'
# 'Multi Matches: 3'
# 'Non-Matches: 341'
# 'Total news sources: 466'

# %%
matches;

# %%
# %whos list
# Out:
# Variable      Type    Data/Info
# -------------------------------
# matches       list    n=117
# non_matches   list    n=341

# %%
#matches = []
#non_matches = []
non_matches_the = []
non_match = 0
multimatch = 0
for gn in non_matches:
    count = 0
    for bias in bias_df.news:
        if gn[:4] == 'THE ':
            f = bias.find(gn[4:])
        if f != -1:
            if count == 0:
                first_match = gn
                fm = bias
                #value = bias_df.loc[bias_df.news == first_match[4:], 'bias'].values[0]
            elif count == 1:
                print()
                print('MULTI-MATCH!')
                print(f'Global: {first_match}, Bias: {fm}')
                print(f'Global: {gn}, Bias: {bias}')
            elif count > 1:
                print(f'Global: {gn}, Bias: {bias}')
            count += 1
        elif f == -1:
            continue
    if count == 0:
        non_matches_the.append(gn)
        non_match += 1
    if count == 1:
        print()
        print('ONE MATCH!')
        print(f'Global: {first_match}, Bias: {fm}')
        if first_match[4:] == fm:
            value = bias_df.loc[bias_df.news == first_match[4:], 'bias'].values[0]
        matches.append((first_match, value))
    elif count > 1:
        print(f'Number of false matches: {count - 1}')
        print()
        multimatch += 1
display(f'Single Matches: {len(matches)}')
display(f'Multi Matches: {multimatch}')
display(f'Non-Matches: {len(non_matches_the)}')
display(f'Total news sources: {len(global_news)}')
# Out:
# ONE MATCH!
# Global: THE ARIZONA REPUBLIC, Bias: ARIZONA REPUBLIC
#
# ONE MATCH!
# Global: THE ATLANTA JOURNAL-CONSTITUTION, Bias: ATLANTA JOURNAL-CONSTITUTION
#
# ONE MATCH!
# Global: THE BALTIMORE SUN, Bias: BALTIMORE SUN
#
# MULTI-MATCH!
# Global: THE BLADE, Bias: AFTONBLADET
# Global: THE BLADE, Bias: TOLEDO BLADE
# Global: THE BLADE, Bias: WASHINGTON BLADE
# Number of false matches: 2
#
#
# ONE MATCH!
# Global: THE BOSTON GLOBE, Bias: BOSTON GLOBE
#
# ONE MATCH!
# Global: THE BUFFALO NEWS, Bias: BUFFALO NEWS
#
# ONE MATCH!
# Global: THE BUSINESS TIMES, Bias: INTERNATIONAL BUSINESS TIMES
#
# ONE MATCH!
# Global: THE CHARLOTTE OBSERVER, Bias: CHARLOTTE OBSERVER
#
# ONE MATCH!
# Global: THE CHRISTIAN SCIENCE MONITOR, Bias: CHRISTIAN SCIENCE MONITOR
#
# ONE MATCH!
# Global: THE COLUMBUS DISPATCH, Bias: COLUMBUS DISPATCH
#
# ONE MATCH!
# Global: THE DALLAS MORNING NEWS, Bias: DALLAS MORNING NEWS
#
# ONE MATCH!
# Global: THE DENVER POST, Bias: DENVER POST
#
# ONE MATCH!
# Global: THE DES MOINES REGISTER, Bias: DES MOINES REGISTER
#
# ONE MATCH!
# Global: THE DETROIT NEWS, Bias: DETROIT NEWS
#
# MULTI-MATCH!
# Global: THE EXAMINER, Bias: EDMONTON EXAMINER
# Global: THE EXAMINER, Bias: LIBERAL EXAMINER
# Global: THE EXAMINER, Bias: SAN FRANCISCO EXAMINER
# Global: THE EXAMINER, Bias: UTAH STANDARD-EXAMINER
# Global: THE EXAMINER, Bias: WASHINGTON EXAMINER
# Number of false matches: 4
#
#
# MULTI-MATCH!
# Global: THE FINANCIAL, Bias: FINANCIAL EXPRESS
# Global: THE FINANCIAL, Bias: FINANCIAL POST
# Global: THE FINANCIAL, Bias: FINANCIAL TIMES
# Global: THE FINANCIAL, Bias: THE AUSTRALIAN FINANCIAL REVIEW
# Number of false matches: 3
#
#
# ONE MATCH!
# Global: THE FINANCIAL EXPRESS, Bias: FINANCIAL EXPRESS
#
# ONE MATCH!
# Global: THE HINDU BUSINESS LINE, Bias: HINDU BUSINESS LINE
#
# ONE MATCH!
# Global: THE HINDUSTAN TIMES, Bias: HINDUSTAN TIMES
#
# ONE MATCH!
# Global: THE HOLLYWOOD REPORTER, Bias: HOLLYWOOD REPORTER
#
# ONE MATCH!
# Global: THE INDIANAPOLIS STAR, Bias: INDIANAPOLIS STAR
#
# ONE MATCH!
# Global: THE KANSAS CITY STAR, Bias: KANSAS CITY STAR
#
# ONE MATCH!
# Global: THE MANILA TIMES, Bias: MANILA TIMES
#
# MULTI-MATCH!
# Global: THE MERCURY, Bias: LEICESTER MERCURY
# Global: THE MERCURY, Bias: SAN JOSE MERCURY NEWS
# Global: THE MERCURY, Bias: VIRGINIA MERCURY
# Number of false matches: 2
#
#
# ONE MATCH!
# Global: THE MIAMI HERALD, Bias: MIAMI HERALD
#
# ONE MATCH!
# Global: THE MOSCOW TIMES, Bias: MOSCOW TIMES
#
# ONE MATCH!
# Global: THE NEW TIMES, Bias: MIAMI NEW TIMES
#
# ONE MATCH!
# Global: THE NEW YORK OBSERVER, Bias: NEW YORK OBSERVER
#
# ONE MATCH!
# Global: THE NEW YORK TIMES, Bias: NEW YORK TIMES
#
# ONE MATCH!
# Global: THE NEW ZEALAND HERALD, Bias: NEW ZEALAND HERALD
#
# ONE MATCH!
# Global: THE NEWS & OBSERVER, Bias: RALEIGH NEWS & OBSERVER
#
# ONE MATCH!
# Global: THE ORANGE COUNTY REGISTER, Bias: ORANGE COUNTY REGISTER
#
# ONE MATCH!
# Global: THE OREGONIAN, Bias: OREGONIAN
#
# ONE MATCH!
# Global: THE PHILADELPHIA INQUIRER, Bias: PHILADELPHIA INQUIRER
#
# ONE MATCH!
# Global: THE PIONEER, Bias: ST. PAUL PIONEER PRESS
#
# MULTI-MATCH!
# Global: THE PUNCH, Bias: COUNTERPUNCH
# Global: THE PUNCH, Bias: PUNCHING BAG POST
# Number of false matches: 1
#
#
# ONE MATCH!
# Global: THE SACRAMENTO BEE, Bias: SACRAMENTO BEE
#
# ONE MATCH!
# Global: THE SEATTLE TIMES, Bias: SEATTLE TIMES
#
# MULTI-MATCH!
# Global: THE STATESMAN, Bias: AUSTIN AMERICAN-STATESMAN
# Global: THE STATESMAN, Bias: DC STATESMAN
# Global: THE STATESMAN, Bias: IDAHO STATESMAN
# Global: THE STATESMAN, Bias: NEW STATESMAN
# Global: THE STATESMAN, Bias: STATESMAN JOURNAL
# Number of false matches: 4
#
#
# MULTI-MATCH!
# Global: THE STREET, Bias: BLACK MAIN STREET
# Global: THE STREET, Bias: EGYPTIAN STREETS
# Global: THE STREET, Bias: R STREET INSTITUTE
# Global: THE STREET, Bias: THESTREET
# Global: THE STREET, Bias: WALL STREET JOURNAL
# Global: THE STREET, Bias: WALL STREET ON PARADE
# Number of false matches: 5
#
#
# MULTI-MATCH!
# Global: THE TELEGRAPH, Bias: DAILY TELEGRAPH
# Global: THE TELEGRAPH, Bias: JEWISH TELEGRAPHIC AGENCY
# Global: THE TELEGRAPH, Bias: THE DAILY TELEGRAPH
# Global: THE TELEGRAPH, Bias: THE MACON TELEGRAPH
# Number of false matches: 3
#
#
# MULTI-MATCH!
# Global: THE TRIBUNE, Bias: ASHEBORO COURIER-TRIBUNE
# Global: THE TRIBUNE, Bias: BISMARCK TRIBUNE
# Global: THE TRIBUNE, Bias: CASPER STAR-TRIBUNE
# Global: THE TRIBUNE, Bias: CHICAGO TRIBUNE
# Global: THE TRIBUNE, Bias: DULUTH NEWS TRIBUNE
# Global: THE TRIBUNE, Bias: EAGLE TRIBUNE
# Global: THE TRIBUNE, Bias: GREAT FALLS TRIBUNE
# Global: THE TRIBUNE, Bias: GREELEY TRIBUNE
# Global: THE TRIBUNE, Bias: HASTINGS TRIBUNE
# Global: THE TRIBUNE, Bias: IDAHO PRESS-TRIBUNE
# Global: THE TRIBUNE, Bias: MINNEAPOLIS STAR-TRIBUNE
# Global: THE TRIBUNE, Bias: PHILADELPHIA TRIBUNE
# Global: THE TRIBUNE, Bias: PITTSBURGH TRIBUNE REVIEW
# Global: THE TRIBUNE, Bias: POLITICAL TRIBUNE
# Global: THE TRIBUNE, Bias: PORTLAND TRIBUNE
# Global: THE TRIBUNE, Bias: SALT LAKE TRIBUNE
# Global: THE TRIBUNE, Bias: SAN DIEGO UNION TRIBUNE
# Global: THE TRIBUNE, Bias: SAN LUIS OBISPO TRIBUNE
# Global: THE TRIBUNE, Bias: SARASOTA HERALD-TRIBUNE
# Global: THE TRIBUNE, Bias: SOUTH BEND TRIBUNE
# Global: THE TRIBUNE, Bias: TEXAS TRIBUNE
# Global: THE TRIBUNE, Bias: THE NEWS TRIBUNE
# Global: THE TRIBUNE, Bias: TRIBUNE CONTENT AGENCY
# Global: THE TRIBUNE, Bias: WACO TRIBUNE-HERALD
# Global: THE TRIBUNE, Bias: WEST CENTRAL TRIBUNE
# Global: THE TRIBUNE, Bias: WIKITRIBUNE
# Global: THE TRIBUNE, Bias: WORLD TRIBUNE
# Number of false matches: 26
#
#
# ONE MATCH!
# Global: THE VANCOUVER SUN, Bias: VANCOUVER SUN
#
# ONE MATCH!
# Global: THE WALL STREET JOURNAL, Bias: WALL STREET JOURNAL
#
# ONE MATCH!
# Global: THE WASHINGTON POST, Bias: WASHINGTON POST
#
# ONE MATCH!
# Global: THE WICHITA EAGLE, Bias: WICHITA EAGLE
# 'Single Matches: 154'
# 'Multi Matches: 9'
# 'Non-Matches: 295'
# 'Total news sources: 466'

# %% [markdown]
# ####

# %%
len(matches)
# Out:
# 154

# %%
non_matches_the;

# %%
# %whos DataFrame
# Out:
# Variable      Type         Data/Info
# ------------------------------------
# bias_df       DataFrame                      news  b<...>\n[1920 rows x 2 columns]
# dummy_merge   DataFrame                             <...>n\n[466 rows x 4 columns]
# global_news   DataFrame                             <...>n\n[466 rows x 3 columns]

# %%
bias_dict = {}
for media, score in matches:
    bias_dict.setdefault(media, score)
global_news['bias'] = global_news['news'].map(bias_dict)
global_news
# Out:
#                           news  financial_news  bias
# 0                24/7 WALL ST.               1   0.0
# 1          ABA BANKING JOURNAL               1   NaN
# 2                          ABC               0   1.0
# 3                     ABC NEWS               0  -1.0
# 4    ALTERNATIVE ENERGY STOCKS               1   NaN
# ..                         ...             ...   ...
# 461                 WUXI DAILY               0   NaN
# 462              YAHOO FINANCE               1   NaN
# 463       YANGTSE EVENING POST               0   NaN
# 464  ZACKS INVESTMENT RESEARCH               1   NaN
# 465            ZHONGSHAN DAILY               0   NaN
#
# [466 rows x 3 columns]

# %%
global_news.bias.value_counts()
# Out:
# -1.0    78
#  1.0    39
#  0.0    26
#  2.0     6
# -2.0     5
# Name: bias, dtype: int64

# %%
global_news.isnull().sum()
# Out:
# news                0
# financial_news      0
# bias              312
# dtype: int64

# %%
print('Number of sentiment sources unranked for bias, by news type:')
global_news.groupby(['financial_news'])['bias'].apply(lambda x: x.isnull().sum())
# Out:
# Number of sentiment sources unranked for bias, by news type:
# financial_news
# 0    150
# 1    162
# Name: bias, dtype: int64

# %%
global_news.groupby(['financial_news'])['bias'].apply(lambda x: x.notnull().sum())
# Out:
# financial_news
# 0    135
# 1     19
# Name: bias, dtype: int64

# %%
global_news
# Out:
#                           news  financial_news  bias
# 0                24/7 WALL ST.               1   0.0
# 1          ABA BANKING JOURNAL               1   NaN
# 2                          ABC               0   1.0
# 3                     ABC NEWS               0  -1.0
# 4    ALTERNATIVE ENERGY STOCKS               1   NaN
# ..                         ...             ...   ...
# 461                 WUXI DAILY               0   NaN
# 462              YAHOO FINANCE               1   NaN
# 463       YANGTSE EVENING POST               0   NaN
# 464  ZACKS INVESTMENT RESEARCH               1   NaN
# 465            ZHONGSHAN DAILY               0   NaN
#
# [466 rows x 3 columns]

# %%
#global_news.to_csv(r'../../data/News_AI_Sentiments/news_media.csv', index = False)

# %%
scored_media = global_news[global_news['bias'].notnull()]
scored_media
# Out:
#                      news  financial_news  bias
# 0           24/7 WALL ST.               1   0.0
# 2                     ABC               0   1.0
# 3                ABC NEWS               0  -1.0
# 6    ANCHORAGE DAILY NEWS               0  -1.0
# 12     ARIZONA DAILY STAR               0  -1.0
# ..                    ...             ...   ...
# 426     THE WICHITA EAGLE               0   1.0
# 432          TORONTO STAR               0  -1.0
# 433           TORONTO SUN               0   2.0
# 441             USA TODAY               0  -1.0
# 456   WINNIPEG FREE PRESS               0   0.0
#
# [154 rows x 3 columns]

# %%
sns.distplot(scored_media.bias, bins =5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     324         try:
# --> 325             result = np.array([to_rgba(cc, alpha) for cc in c])
#     326         except ValueError:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in <listcomp>(.0)
#     324         try:
# --> 325             result = np.array([to_rgba(cc, alpha) for cc in c])
#     326         except ValueError:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     184     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 185         rgba = _to_rgba_no_colorcycle(c, alpha)
#     186         try:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     260             return c, c, c, alpha if alpha is not None else 1.
# --> 261         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     262     # tuple color.
#
# ValueError: Invalid RGBA argument: 'f'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-170-1f0912ccf642> in <module>
# ----> 1 sns.distplot(scored_media.bias, color= 'financial_news',bins =5)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     219         orientation = "horizontal" if vertical else "vertical"
#     220         hist_color = hist_kws.pop("color", color)
# --> 221         ax.hist(a, bins, orientation=orientation,
#     222                 color=hist_color, **hist_kws)
#     223         if hist_color != color:
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6609             color = [self._get_lines.get_next_color() for i in range(nx)]
#    6610         else:
# -> 6611             color = mcolors.to_rgba_array(color)
#    6612             if len(color) != nx:
#    6613                 error_message = (
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     325             result = np.array([to_rgba(cc, alpha) for cc in c])
#     326         except ValueError:
# --> 327             raise ValueError(
#     328                 "'%s' is neither a valid single color nor a color sequence "
#     329                 "consisting of single character color specifiers such as "
#
# ValueError: 'financial_news' is neither a valid single color nor a color sequence consisting of single character color specifiers such as 'rgb'. Note also that the latter is deprecated.

# %%
plt.hist(scored_media.bias, label=[-2,-1,0,1,2], bins = 5);
plt.title('Distribution of Media Source by Political & Factual Bias')
plt.ylabel('Frequency');
plt.setp( axs.get_xticklabels(), rotation = 0, rotation_mode='anchor', ha='left');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-159-73a24d035e2c> in <module>
#       2 plt.title('Distribution of Media Source by Political & Factual Bias')
#       3 plt.ylabel('Frequency');
# ----> 4 plt.setp( axs.get_xticklabels(), rotation = 0, rotation_mode='anchor', ha='left');
#
# NameError: name 'axs' is not defined

# %%
(scored_media.bias.sum())/len(media)
# Out:
# -2.176470588235294

# %%
dir_fin = pd.read_csv('../../data/News_AI_Sentiments/news_sources_direct_financial.csv')
total_nans = dir_fin.isnull().sum().sum()

round((dir_fin.isnull().sum()/total_nans)*100,0)
# Out:
# Oil                           0.0
# Fossil Fuel                   5.0
# valero                       10.0
# exxon                         7.0
# conoco                       13.0
# phillips 66                  10.0
# chevron                       7.0
# occidental petroleum         10.0
# marathon oil                 11.0
# pioneer natural resources    13.0
# pipeline                      2.0
# oilfield                      8.0
# drilling                      5.0
# dtype: float64

# %%
len(dir_fin[col])
# Out:
# 138

# %%
# %whos dict
# Out:
# Variable         Type    Data/Info
# ----------------------------------
# bias_dict        dict    n=154
# fact_reporting   dict    n=6

# %%
bias_dict;

# %%
dir_fin.columns
# Out:
# Index(['Oil', 'Fossil Fuel', 'valero', 'exxon', 'conoco', 'phillips 66',
#        'chevron', 'occidental petroleum', 'marathon oil',
#        'pioneer natural resources', 'pipeline', 'oilfield', 'drilling'],
#       dtype='object')

# %%
count = 0
abs_count = 0
not_ranked = 0

df = dir_fin

for col in df.columns:
    for source in df[col]:
        if source in bias_dict.keys():
            b = bias_dict[source]
            abs_count += np.abs(b)
# Out:
# 138
# 138
# 138
# 138
# 138
# 138
# 138
# 138
# 138
# 138
# 138
# 138
# 138
