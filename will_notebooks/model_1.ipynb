# %%
import pandas as pd

# %%
target = pd.read_excel('../data/Financial_Market/NYSE_closing_price.xlsx')

# %%
sentNA = pd.read_csv('../data/News_AI_Sentiments/daily-news-sentiment-NA.csv')

# %%
sentINT = pd.read_csv('../data/News_AI_Sentiments/daily-news-sentiment-international.csv')

# %%
#preview
target.head()
# Out:
#    Value        Date Super Region Ticker Time Level        Source  \
# 0  36.67  2020-08-07  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
# 1  67.68  2018-03-07  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
# 2  46.23  2021-01-25  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
# 3  35.73  2020-08-06  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
# 4  67.39  2018-03-06  GLOBAL DATA    MPC      DAILY  WORLDDATA.AI
#
#                        Stock Name                  Sub-Sector Stock Attribute  \
# 0  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
# 1  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
# 2  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
# 3  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
# 4  MARATHON PETROLEUM CORPORATION  GLOBAL STOCK EXCHANGE DATA   CLOSING PRICE
#
#   Currency            Data Provider                          Stock Exchange  \
# 0      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
# 1      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
# 2      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
# 3      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
# 4      USD  NEW YORK STOCK EXCHANGE  NEW YORK STOCK EXCHANGE - STOCK PRICES
#
#            Location
# 0  AMERICA-NEW_YORK
# 1  AMERICA-NEW_YORK
# 2  AMERICA-NEW_YORK
# 3  AMERICA-NEW_YORK
# 4  AMERICA-NEW_YORK

# %%
target['Stock Name'].value_counts()
# Out:
# MARATHON OIL CORPORATION             1000
# CONOCOPHILLIPS                       1000
# PIONEER NATURAL RESOURCES COMPANY    1000
# EXXON MOBIL CORPORATION              1000
# VALERO ENERGY CORPORATION            1000
# PHILLIPS 66                          1000
# BP P.L.C.                            1000
# MARATHON PETROLEUM CORPORATION       1000
# OCCIDENTAL PETROLEUM CORPORATION     1000
# CHEVRON CORPORATION                  1000
# Name: Stock Name, dtype: int64

# %%
target.dtypes
# Out:
# Value              float64
# Date                object
# Super Region        object
# Ticker              object
# Time Level          object
# Source              object
# Stock Name          object
# Sub-Sector          object
# Stock Attribute     object
# Currency            object
# Data Provider       object
# Stock Exchange      object
# Location            object
# dtype: object

# %%
target['Date'] = pd.to_datetime(target['Date'])

# %%
target.dtypes
# Out:
# Value                     float64
# Date               datetime64[ns]
# Super Region               object
# Ticker                     object
# Time Level                 object
# Source                     object
# Stock Name                 object
# Sub-Sector                 object
# Stock Attribute            object
# Currency                   object
# Data Provider              object
# Stock Exchange             object
# Location                   object
# dtype: object

# %%
#keep only Exxon prices
target = target[target['Stock Name'] == 'EXXON MOBIL CORPORATION'].copy()

# %%
target.shape
# Out:
# (1000, 13)

# %%
target.columns
# Out:
# Index(['Value', 'Date', 'Super Region', 'Ticker', 'Time Level', 'Source',
#        'Stock Name', 'Sub-Sector', 'Stock Attribute', 'Currency',
#        'Data Provider', 'Stock Exchange', 'Location'],
#       dtype='object')

# %%
target['Date'].value_counts() #confirming only a single date now for each row
# Out:
# 2017-10-30    1
# 2017-08-31    1
# 2020-07-14    1
# 2018-04-02    1
# 2018-04-16    1
#              ..
# 2019-11-04    1
# 2019-06-04    1
# 2017-08-16    1
# 2020-11-25    1
# 2020-02-11    1
# Name: Date, Length: 1000, dtype: int64

# %%
exxon = target[['Date', 'Value']]

# %%
exxon.reset_index(inplace=True)

# %%
exxon = exxon[['Date', 'Value']].copy()

# %%
exxon
# Out:
#           Date  Value
# 0   2020-08-07  43.44
# 1   2018-03-07  74.26
# 2   2021-01-25  46.90
# 3   2020-08-06  43.64
# 4   2018-03-06  76.18
# ..         ...    ...
# 995 2019-07-05  76.13
# 996 2019-07-08  76.48
# 997 2018-07-20  81.40
# 998 2019-07-09  76.43
# 999 2017-07-31  80.04
#
# [1000 rows x 2 columns]

# %%
exxon = exxon.sort_values(by='Date') #range of dates

# %%
exxon.reset_index(inplace=True) #match index numbers to order of dates
exxon = exxon[['Date', 'Value']].copy()
exxon
# Out:
#           Date  Value
# 0   2017-02-28  81.32
# 1   2017-03-01  83.02
# 2   2017-03-02  83.30
# 3   2017-03-03  82.46
# 4   2017-03-06  82.83
# ..         ...    ...
# 995 2021-02-19  52.37
# 996 2021-02-22  54.30
# 997 2021-02-23  55.05
# 998 2021-02-24  56.70
# 999 2021-02-25  55.76
#
# [1000 rows x 2 columns]

# %%
sentINT.head() #preview
# Out:
#           DateTime  Daily News Sentiment
# 0   4/17/2000 0:00                  -0.1
# 1    8/1/2000 0:00                   0.2
# 2   1/24/2001 0:00                   0.2
# 3    4/4/2001 0:00                  -0.1
# 4  10/31/2002 0:00                  -0.5

# %%
sentINT.dtypes
# Out:
# DateTime                 object
# Daily News Sentiment    float64
# dtype: object

# %%
sentINT['DateTime'] = pd.to_datetime(sentINT['DateTime'])

# %%
sentINT.dtypes
# Out:
# DateTime                datetime64[ns]
# Daily News Sentiment           float64
# dtype: object

# %%
sentINT.sort_values(by='DateTime') #preview
# Out:
#       DateTime  Daily News Sentiment
# 0   2000-04-17                 -0.10
# 1   2000-08-01                  0.20
# 2   2001-01-24                  0.20
# 3   2001-04-04                 -0.10
# 4   2002-10-31                 -0.50
# ..         ...                   ...
# 390 2021-02-23                 -0.27
# 391 2021-02-24                 -0.10
# 392 2021-02-25                  0.00
# 393 2021-02-26                 -0.30
# 394 2021-02-27                 -0.10
#
# [395 rows x 2 columns]

# %%
sentINT = sentINT.sort_values(by='DateTime') #make permanent

# %%
sentINT
# Out:
#       DateTime  Daily News Sentiment
# 0   2000-04-17                 -0.10
# 1   2000-08-01                  0.20
# 2   2001-01-24                  0.20
# 3   2001-04-04                 -0.10
# 4   2002-10-31                 -0.50
# ..         ...                   ...
# 390 2021-02-23                 -0.27
# 391 2021-02-24                 -0.10
# 392 2021-02-25                  0.00
# 393 2021-02-26                 -0.30
# 394 2021-02-27                 -0.10
#
# [395 rows x 2 columns]

# %%
sentNA.head() #preview
# Out:
#          DateTime  Daily News Sentiment
# 0  7/26/2013 0:00                   0.1
# 1   8/1/2013 0:00                  -0.5
# 2   8/8/2013 0:00                   0.1
# 3   8/9/2013 0:00                   0.1
# 4  8/17/2013 0:00                   0.2

# %%
sentNA['DateTime'] = pd.to_datetime(sentNA['DateTime']) #perform same changes as on INT df
sentNA = sentNA.sort_values(by='DateTime')

# %%
sentNA #preview
# Out:
#       DateTime  Daily News Sentiment
# 0   2013-07-26                  0.10
# 1   2013-08-01                 -0.50
# 2   2013-08-08                  0.10
# 3   2013-08-09                  0.10
# 4   2013-08-17                  0.20
# ..         ...                   ...
# 391 2021-02-23                 -0.50
# 392 2021-02-24                 -0.50
# 393 2021-02-25                  0.07
# 394 2021-02-26                 -0.40
# 395 2021-02-27                 -0.60
#
# [396 rows x 2 columns]

# %% [markdown]
# Need to join all 3 dfs together in order to run models predicting close price. (join on date)

# %%
exxon = exxon.set_index(keys='Date')
exxon
# Out:
#             Value
# Date
# 2017-02-28  81.32
# 2017-03-01  83.02
# 2017-03-02  83.30
# 2017-03-03  82.46
# 2017-03-06  82.83
# ...           ...
# 2021-02-19  52.37
# 2021-02-22  54.30
# 2021-02-23  55.05
# 2021-02-24  56.70
# 2021-02-25  55.76
#
# [1000 rows x 1 columns]

# %%
sentINT = sentINT.set_index(keys='DateTime')

# %%
sentINT #preview
# Out:
#             Daily News Sentiment
# DateTime
# 2000-04-17                 -0.10
# 2000-08-01                  0.20
# 2001-01-24                  0.20
# 2001-04-04                 -0.10
# 2002-10-31                 -0.50
# ...                          ...
# 2021-02-23                 -0.27
# 2021-02-24                 -0.10
# 2021-02-25                  0.00
# 2021-02-26                 -0.30
# 2021-02-27                 -0.10
#
# [395 rows x 1 columns]

# %%
sentNA = sentNA.set_index(keys='DateTime')
sentNA #preview
# Out:
#             Daily News Sentiment
# DateTime
# 2013-07-26                  0.10
# 2013-08-01                 -0.50
# 2013-08-08                  0.10
# 2013-08-09                  0.10
# 2013-08-17                  0.20
# ...                          ...
# 2021-02-23                 -0.50
# 2021-02-24                 -0.50
# 2021-02-25                  0.07
# 2021-02-26                 -0.40
# 2021-02-27                 -0.60
#
# [396 rows x 1 columns]

# %% [markdown]
# Dates are now set as indexes, making the join easier

# %%
all_sent = sentINT.join(sentNA, how='outer', lsuffix = '_INT', rsuffix = '_NA') #join both sentiment dfs

# %%
all_sent #preview
# Out:
#             Daily News Sentiment_INT  Daily News Sentiment_NA
# DateTime
# 2000-04-17                     -0.10                      NaN
# 2000-08-01                      0.20                      NaN
# 2001-01-24                      0.20                      NaN
# 2001-04-04                     -0.10                      NaN
# 2002-10-31                     -0.50                      NaN
# ...                              ...                      ...
# 2021-02-23                     -0.27                    -0.50
# 2021-02-24                     -0.10                    -0.50
# 2021-02-25                      0.00                     0.07
# 2021-02-26                     -0.30                    -0.40
# 2021-02-27                     -0.10                    -0.60
#
# [676 rows x 2 columns]

# %%
all_sent.isnull().sum()
# Out:
# Daily News Sentiment_INT    281
# Daily News Sentiment_NA     280
# dtype: int64

# %%
all_sent.tail(20)
# Out:
#             Daily News Sentiment_INT  Daily News Sentiment_NA
# DateTime
# 2021-01-29                     -0.50                    -0.05
# 2021-01-30                      0.02                      NaN
# 2021-02-01                       NaN                    -0.23
# 2021-02-02                     -0.22                    -0.30
# 2021-02-03                     -0.15                    -0.18
# 2021-02-06                       NaN                     0.10
# 2021-02-09                     -0.27                      NaN
# 2021-02-10                      0.20                    -0.10
# 2021-02-12                     -0.10                      NaN
# 2021-02-14                     -0.20                     0.10
# 2021-02-16                     -0.20                      NaN
# 2021-02-17                     -0.10                      NaN
# 2021-02-18                     -0.25                      NaN
# 2021-02-20                     -0.15                      NaN
# 2021-02-21                     -0.20                      NaN
# 2021-02-23                     -0.27                    -0.50
# 2021-02-24                     -0.10                    -0.50
# 2021-02-25                      0.00                     0.07
# 2021-02-26                     -0.30                    -0.40
# 2021-02-27                     -0.10                    -0.60

# %%
df = exxon.join(all_sent)

# %%
df.isnull().sum()
# Out:
# Value                         0
# Daily News Sentiment_INT    782
# Daily News Sentiment_NA     780
# dtype: int64

# %% [markdown]
# For simplicity in this first crude model, I will use "0" to fill the null values in news sentiment - it's not unreasonable to say that on days in which 'Exxon' did not appear in the news, sentiment towards it was neither positive nor negative, i.e. zero.

# %%
df.fillna(0, inplace=True)

# %%
df #preview
# Out:
#             Value  Daily News Sentiment_INT  Daily News Sentiment_NA
# Date
# 2017-02-28  81.32                      0.00                     0.00
# 2017-03-01  83.02                      0.00                     0.00
# 2017-03-02  83.30                      0.00                    -0.20
# 2017-03-03  82.46                      0.00                     0.00
# 2017-03-06  82.83                     -0.20                    -0.20
# ...           ...                       ...                      ...
# 2021-02-19  52.37                      0.00                     0.00
# 2021-02-22  54.30                      0.00                     0.00
# 2021-02-23  55.05                     -0.27                    -0.50
# 2021-02-24  56.70                     -0.10                    -0.50
# 2021-02-25  55.76                      0.00                     0.07
#
# [1000 rows x 3 columns]

# %%
#df.to_csv('exxon_sentiment_clean.csv')

# %%
df.rename(columns={'Value':'Exxon_close_price'}, inplace=True) #clarify target variable

# %%
df.head() #preview
# Out:
#             Exxon_close_price  Daily News Sentiment_INT  \
# Date
# 2017-02-28              81.32                       0.0
# 2017-03-01              83.02                       0.0
# 2017-03-02              83.30                       0.0
# 2017-03-03              82.46                       0.0
# 2017-03-06              82.83                      -0.2
#
#             Daily News Sentiment_NA
# Date
# 2017-02-28                      0.0
# 2017-03-01                      0.0
# 2017-03-02                     -0.2
# 2017-03-03                      0.0
# 2017-03-06                     -0.2

# %%
#time to join the previously distilled mobility scores as additional features

# %%
mobility = pd.read_csv('../apple_mobility_top5countries.csv')

# %%
mobility.head() #preview
# Out:
#          Date  Value_ger_walk  Value_ger_drive  Value_ger_trans  \
# 0  2020-01-13      100.000000       100.000000       100.000000
# 1  2020-01-14      103.183824       100.824118       100.482778
# 2  2020-01-15      106.456471       102.264706        99.780000
# 3  2020-01-16      109.984118       104.645882       100.437778
# 4  2020-01-17      123.211176       114.010294       108.340000
#
#    Value_ind_walk  Value_ind_drive  Value_rus_walk  Value_rus_drive  \
# 0      100.000000       100.000000        100.0000         100.0000
# 1       98.036667        97.018333        103.6425         100.5600
# 2      100.060000        96.381667        102.9575         101.9925
# 3      101.966667       101.233333        108.3575         104.2175
# 4      110.888333       115.590000        110.8375         108.7100
#
#    Value_us_walk  Value_us_drive  Value_us_trans  Value_jap_walk  \
# 0     100.000000      100.000000      100.000000      100.000000
# 1     101.940784      103.007547       99.727907      100.745745
# 2     101.752353      104.364528       98.963256      104.023191
# 3     102.251373      107.985849       99.501860      114.933830
# 4     121.800784      122.748868      105.785814      152.478723
#
#    Value_jap_drive  Value_jap_trans
# 0       100.000000       100.000000
# 1        99.272340       100.258511
# 2       100.096596       101.187447
# 3       104.993617       108.546383
# 4       130.354468       133.495532

# %%
mobility.set_index(pd.to_datetime(mobility['Date']), inplace=True)

# %%
mobility.drop(columns='Date', inplace=True) #drop former date column now that it is index

# %%
mobility.head() #confirm changes
# Out:
#             Value_ger_walk  Value_ger_drive  Value_ger_trans  Value_ind_walk  \
# Date
# 2020-01-13      100.000000       100.000000       100.000000      100.000000
# 2020-01-14      103.183824       100.824118       100.482778       98.036667
# 2020-01-15      106.456471       102.264706        99.780000      100.060000
# 2020-01-16      109.984118       104.645882       100.437778      101.966667
# 2020-01-17      123.211176       114.010294       108.340000      110.888333
#
#             Value_ind_drive  Value_rus_walk  Value_rus_drive  Value_us_walk  \
# Date
# 2020-01-13       100.000000        100.0000         100.0000     100.000000
# 2020-01-14        97.018333        103.6425         100.5600     101.940784
# 2020-01-15        96.381667        102.9575         101.9925     101.752353
# 2020-01-16       101.233333        108.3575         104.2175     102.251373
# 2020-01-17       115.590000        110.8375         108.7100     121.800784
#
#             Value_us_drive  Value_us_trans  Value_jap_walk  Value_jap_drive  \
# Date
# 2020-01-13      100.000000      100.000000      100.000000       100.000000
# 2020-01-14      103.007547       99.727907      100.745745        99.272340
# 2020-01-15      104.364528       98.963256      104.023191       100.096596
# 2020-01-16      107.985849       99.501860      114.933830       104.993617
# 2020-01-17      122.748868      105.785814      152.478723       130.354468
#
#             Value_jap_trans
# Date
# 2020-01-13       100.000000
# 2020-01-14       100.258511
# 2020-01-15       101.187447
# 2020-01-16       108.546383
# 2020-01-17       133.495532

# %%
allfeats = df.join(mobility).copy()

# %%
allfeats.head() #preview
# Out:
#             Exxon_close_price  Daily News Sentiment_INT  \
# Date
# 2017-02-28              81.32                       0.0
# 2017-03-01              83.02                       0.0
# 2017-03-02              83.30                       0.0
# 2017-03-03              82.46                       0.0
# 2017-03-06              82.83                      -0.2
#
#             Daily News Sentiment_NA  Value_ger_walk  Value_ger_drive  \
# Date
# 2017-02-28                      0.0             NaN              NaN
# 2017-03-01                      0.0             NaN              NaN
# 2017-03-02                     -0.2             NaN              NaN
# 2017-03-03                      0.0             NaN              NaN
# 2017-03-06                     -0.2             NaN              NaN
#
#             Value_ger_trans  Value_ind_walk  Value_ind_drive  Value_rus_walk  \
# Date
# 2017-02-28              NaN             NaN              NaN             NaN
# 2017-03-01              NaN             NaN              NaN             NaN
# 2017-03-02              NaN             NaN              NaN             NaN
# 2017-03-03              NaN             NaN              NaN             NaN
# 2017-03-06              NaN             NaN              NaN             NaN
#
#             Value_rus_drive  Value_us_walk  Value_us_drive  Value_us_trans  \
# Date
# 2017-02-28              NaN            NaN             NaN             NaN
# 2017-03-01              NaN            NaN             NaN             NaN
# 2017-03-02              NaN            NaN             NaN             NaN
# 2017-03-03              NaN            NaN             NaN             NaN
# 2017-03-06              NaN            NaN             NaN             NaN
#
#             Value_jap_walk  Value_jap_drive  Value_jap_trans
# Date
# 2017-02-28             NaN              NaN              NaN
# 2017-03-01             NaN              NaN              NaN
# 2017-03-02             NaN              NaN              NaN
# 2017-03-03             NaN              NaN              NaN
# 2017-03-06             NaN              NaN              NaN

# %%
#dropping nulls for this first model
allfeats.dropna(inplace=True)

# %%
allfeats.head() #confirm
# Out:
#             Exxon_close_price  Daily News Sentiment_INT  \
# Date
# 2020-01-13              69.80                       0.0
# 2020-01-14              69.20                       0.0
# 2020-01-15              69.09                       0.0
# 2020-01-16              68.82                       0.0
# 2020-01-17              68.56                       0.0
#
#             Daily News Sentiment_NA  Value_ger_walk  Value_ger_drive  \
# Date
# 2020-01-13                      0.0      100.000000       100.000000
# 2020-01-14                      0.0      103.183824       100.824118
# 2020-01-15                      0.0      106.456471       102.264706
# 2020-01-16                     -0.5      109.984118       104.645882
# 2020-01-17                      0.1      123.211176       114.010294
#
#             Value_ger_trans  Value_ind_walk  Value_ind_drive  Value_rus_walk  \
# Date
# 2020-01-13       100.000000      100.000000       100.000000        100.0000
# 2020-01-14       100.482778       98.036667        97.018333        103.6425
# 2020-01-15        99.780000      100.060000        96.381667        102.9575
# 2020-01-16       100.437778      101.966667       101.233333        108.3575
# 2020-01-17       108.340000      110.888333       115.590000        110.8375
#
#             Value_rus_drive  Value_us_walk  Value_us_drive  Value_us_trans  \
# Date
# 2020-01-13         100.0000     100.000000      100.000000      100.000000
# 2020-01-14         100.5600     101.940784      103.007547       99.727907
# 2020-01-15         101.9925     101.752353      104.364528       98.963256
# 2020-01-16         104.2175     102.251373      107.985849       99.501860
# 2020-01-17         108.7100     121.800784      122.748868      105.785814
#
#             Value_jap_walk  Value_jap_drive  Value_jap_trans
# Date
# 2020-01-13      100.000000       100.000000       100.000000
# 2020-01-14      100.745745        99.272340       100.258511
# 2020-01-15      104.023191       100.096596       101.187447
# 2020-01-16      114.933830       104.993617       108.546383
# 2020-01-17      152.478723       130.354468       133.495532

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
def plot_series(df, cols, title='Title', xlab=None, ylab=None): #from GA DSI Lesson 10.2 taught by Dan Wilhelm
    plt.figure(figsize=(18,9))
    for col in cols:
        plt.plot(df[col])
    plt.title(title, fontsize=26)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    
    plt.xticks(fontsize=18)
    plt.yticks(fontsize=18)

# %%
plot_series(allfeats, ['Exxon_close_price'], title='Exxon Close Price', ylab='USD$') #just the target

# %%
plot_series(allfeats, ['Exxon_close_price', 
                       'Daily News Sentiment_INT',
                      'Daily News Sentiment_NA'],
           title='Exxon Close Price and News Sentiment') 
#plt.legend()
#scale is a problem - closing price in $, sentiment is -1 to 1

# %%
#check seasonality
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
#if time series index is daily then the default period is 7 days
decomp = seasonal_decompose(allfeats['Exxon_close_price'], period=7)
decomp.plot();

# %%
#top is original(observed) data
#subtract middle 2 graphs (trend + seasonal)
    #trend is a moving average
    #no strong seasonal component (range of -.2 to .2) is much smaller than data
#end up with residuals (bottom graph)

# %%
allfeats['lag_1'] = allfeats['Exxon_close_price'].shift(1)
allfeats['lag_2'] = allfeats['Exxon_close_price'].shift(2)
allfeats['lag_3'] = allfeats['Exxon_close_price'].shift(3)

# %%
allfeats.head() #preview
# Out:
#             Exxon_close_price  Daily News Sentiment_INT  \
# Date
# 2020-01-13              69.80                       0.0
# 2020-01-14              69.20                       0.0
# 2020-01-15              69.09                       0.0
# 2020-01-16              68.82                       0.0
# 2020-01-17              68.56                       0.0
#
#             Daily News Sentiment_NA  Value_ger_walk  Value_ger_drive  \
# Date
# 2020-01-13                      0.0      100.000000       100.000000
# 2020-01-14                      0.0      103.183824       100.824118
# 2020-01-15                      0.0      106.456471       102.264706
# 2020-01-16                     -0.5      109.984118       104.645882
# 2020-01-17                      0.1      123.211176       114.010294
#
#             Value_ger_trans  Value_ind_walk  Value_ind_drive  Value_rus_walk  \
# Date
# 2020-01-13       100.000000      100.000000       100.000000        100.0000
# 2020-01-14       100.482778       98.036667        97.018333        103.6425
# 2020-01-15        99.780000      100.060000        96.381667        102.9575
# 2020-01-16       100.437778      101.966667       101.233333        108.3575
# 2020-01-17       108.340000      110.888333       115.590000        110.8375
#
#             Value_rus_drive  Value_us_walk  Value_us_drive  Value_us_trans  \
# Date
# 2020-01-13         100.0000     100.000000      100.000000      100.000000
# 2020-01-14         100.5600     101.940784      103.007547       99.727907
# 2020-01-15         101.9925     101.752353      104.364528       98.963256
# 2020-01-16         104.2175     102.251373      107.985849       99.501860
# 2020-01-17         108.7100     121.800784      122.748868      105.785814
#
#             Value_jap_walk  Value_jap_drive  Value_jap_trans  lag_1  lag_2  \
# Date
# 2020-01-13      100.000000       100.000000       100.000000    NaN    NaN
# 2020-01-14      100.745745        99.272340       100.258511  69.80    NaN
# 2020-01-15      104.023191       100.096596       101.187447  69.20  69.80
# 2020-01-16      114.933830       104.993617       108.546383  69.09  69.20
# 2020-01-17      152.478723       130.354468       133.495532  68.82  69.09
#
#             lag_3
# Date
# 2020-01-13    NaN
# 2020-01-14    NaN
# 2020-01-15    NaN
# 2020-01-16   69.8
# 2020-01-17   69.2

# %%
allfeats.plot.scatter(x='Exxon_close_price', y='lag_1') #should be highly correlated (autocorrelation)

# %%
import seaborn as sns #correlation heatmap
corr = allfeats.corr()
plt.figure(figsize=(40,20))
plt.xticks(size=25)
plt.yticks(size=25)
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(allfeats.corr(), mask=mask, annot=True, cmap='coolwarm', vmin=-1, vmax=1,
           annot_kws={'size':25}); #vmin and vmax set scale for color shades

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(allfeats['Exxon_close_price'], lags=20);

# %%
#including lag 2 won't have much effect if we are already including lag 1

# %%
allfeats.drop(columns=['lag_2', 'lag_3'], inplace=True)

# %%
allfeats.head() #preview
# Out:
#             Exxon_close_price  Daily News Sentiment_INT  \
# Date
# 2020-01-13              69.80                       0.0
# 2020-01-14              69.20                       0.0
# 2020-01-15              69.09                       0.0
# 2020-01-16              68.82                       0.0
# 2020-01-17              68.56                       0.0
#
#             Daily News Sentiment_NA  Value_ger_walk  Value_ger_drive  \
# Date
# 2020-01-13                      0.0      100.000000       100.000000
# 2020-01-14                      0.0      103.183824       100.824118
# 2020-01-15                      0.0      106.456471       102.264706
# 2020-01-16                     -0.5      109.984118       104.645882
# 2020-01-17                      0.1      123.211176       114.010294
#
#             Value_ger_trans  Value_ind_walk  Value_ind_drive  Value_rus_walk  \
# Date
# 2020-01-13       100.000000      100.000000       100.000000        100.0000
# 2020-01-14       100.482778       98.036667        97.018333        103.6425
# 2020-01-15        99.780000      100.060000        96.381667        102.9575
# 2020-01-16       100.437778      101.966667       101.233333        108.3575
# 2020-01-17       108.340000      110.888333       115.590000        110.8375
#
#             Value_rus_drive  Value_us_walk  Value_us_drive  Value_us_trans  \
# Date
# 2020-01-13         100.0000     100.000000      100.000000      100.000000
# 2020-01-14         100.5600     101.940784      103.007547       99.727907
# 2020-01-15         101.9925     101.752353      104.364528       98.963256
# 2020-01-16         104.2175     102.251373      107.985849       99.501860
# 2020-01-17         108.7100     121.800784      122.748868      105.785814
#
#             Value_jap_walk  Value_jap_drive  Value_jap_trans  lag_1
# Date
# 2020-01-13      100.000000       100.000000       100.000000    NaN
# 2020-01-14      100.745745        99.272340       100.258511  69.80
# 2020-01-15      104.023191       100.096596       101.187447  69.20
# 2020-01-16      114.933830       104.993617       108.546383  69.09
# 2020-01-17      152.478723       130.354468       133.495532  68.82

# %%
allfeats['INT_lag_1'] = allfeats['Daily News Sentiment_INT'].shift(1) #lag INT news
allfeats['NA_lag_1'] = allfeats['Daily News Sentiment_NA'].shift(1) #lag NA news
#allfeats['lag_3'] = allfeats['Exxon_close_price'].shift(1)

# %%
import seaborn as sns #correlation heatmap
corr = allfeats.corr()
plt.figure(figsize=(40,20))
plt.xticks(size=25)
plt.yticks(size=25)
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(allfeats.corr(), mask=mask, annot=True, cmap='coolwarm', vmin=-1, vmax=1,
           annot_kws={'size':25}); #vmin and vmax set scale for color shades

# %%
allfeats.head()
# Out:
#             Exxon_close_price  Daily News Sentiment_INT  \
# Date
# 2020-01-13              69.80                       0.0
# 2020-01-14              69.20                       0.0
# 2020-01-15              69.09                       0.0
# 2020-01-16              68.82                       0.0
# 2020-01-17              68.56                       0.0
#
#             Daily News Sentiment_NA  Value_ger_walk  Value_ger_drive  \
# Date
# 2020-01-13                      0.0      100.000000       100.000000
# 2020-01-14                      0.0      103.183824       100.824118
# 2020-01-15                      0.0      106.456471       102.264706
# 2020-01-16                     -0.5      109.984118       104.645882
# 2020-01-17                      0.1      123.211176       114.010294
#
#             Value_ger_trans  Value_ind_walk  Value_ind_drive  Value_rus_walk  \
# Date
# 2020-01-13       100.000000      100.000000       100.000000        100.0000
# 2020-01-14       100.482778       98.036667        97.018333        103.6425
# 2020-01-15        99.780000      100.060000        96.381667        102.9575
# 2020-01-16       100.437778      101.966667       101.233333        108.3575
# 2020-01-17       108.340000      110.888333       115.590000        110.8375
#
#             Value_rus_drive  Value_us_walk  Value_us_drive  Value_us_trans  \
# Date
# 2020-01-13         100.0000     100.000000      100.000000      100.000000
# 2020-01-14         100.5600     101.940784      103.007547       99.727907
# 2020-01-15         101.9925     101.752353      104.364528       98.963256
# 2020-01-16         104.2175     102.251373      107.985849       99.501860
# 2020-01-17         108.7100     121.800784      122.748868      105.785814
#
#             Value_jap_walk  Value_jap_drive  Value_jap_trans  lag_1  \
# Date
# 2020-01-13      100.000000       100.000000       100.000000    NaN
# 2020-01-14      100.745745        99.272340       100.258511  69.80
# 2020-01-15      104.023191       100.096596       101.187447  69.20
# 2020-01-16      114.933830       104.993617       108.546383  69.09
# 2020-01-17      152.478723       130.354468       133.495532  68.82
#
#             INT_lag_1  NA_lag_1
# Date
# 2020-01-13        NaN       NaN
# 2020-01-14        0.0       0.0
# 2020-01-15        0.0       0.0
# 2020-01-16        0.0       0.0
# 2020-01-17        0.0      -0.5

# %%
allfeats['Value_ger_drive'].shift()

# %%
allfeats.dropna(inplace=True) #drop top NaN row

# %%
X_train, X_test, y_train, y_test = train_test_split(allfeats.drop(columns='Exxon_close_price'),
                                                   allfeats['Exxon_close_price'],
                                                   test_size=.2, #80%/20% train/test split
                                                   shuffle=False) #predict most recent values

# %%
print(
X_train.shape,
y_train.shape,
X_test.shape,
y_test.shape) #verify shape
# Out:
# (219, 16) (219,) (55, 16) (55,)

# %%
import statsmodels.api as sm

# %%
X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test) #add intercepts

# %%
lm = sm.OLS(y_train, X_train)
lm_results = lm.fit()
print(lm_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Exxon_close_price   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     503.5
# Date:                Tue, 16 Mar 2021   Prob (F-statistic):          4.08e-153
# Time:                        17:19:22   Log-Likelihood:                -386.62
# No. Observations:                 219   AIC:                             807.2
# Df Residuals:                     202   BIC:                             864.9
# Df Model:                          16
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        3.7984      1.593      2.385      0.018       0.658       6.939
# Daily News Sentiment_INT     1.1974      0.636      1.884      0.061      -0.056       2.451
# Daily News Sentiment_NA      0.4203      0.708      0.594      0.553      -0.975       1.815
# Value_ger_walk              -0.0244      0.018     -1.359      0.176      -0.060       0.011
# Value_ger_drive              0.0706      0.027      2.605      0.010       0.017       0.124
# Value_ger_trans             -0.0147      0.010     -1.414      0.159      -0.035       0.006
# Value_ind_walk               0.0296      0.033      0.890      0.374      -0.036       0.095
# Value_ind_drive             -0.0238      0.035     -0.672      0.502      -0.094       0.046
# Value_rus_walk              -0.0101      0.013     -0.758      0.449      -0.036       0.016
# Value_rus_drive             -0.0047      0.016     -0.297      0.767      -0.036       0.027
# Value_us_walk                0.0212      0.020      1.069      0.287      -0.018       0.060
# Value_us_drive              -0.0433      0.027     -1.576      0.117      -0.097       0.011
# Value_us_trans               0.0211      0.022      0.965      0.336      -0.022       0.064
# Value_jap_walk              -0.0158      0.017     -0.913      0.362      -0.050       0.018
# Value_jap_drive              0.0165      0.027      0.605      0.546      -0.037       0.070
# Value_jap_trans             -0.0060      0.034     -0.179      0.858      -0.073       0.061
# lag_1                        0.9125      0.033     27.269      0.000       0.847       0.978
# ==============================================================================
# Omnibus:                       23.661   Durbin-Watson:                   2.217
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.083
# Skew:                          -0.326   Prob(JB):                     6.72e-18
# Kurtosis:                       5.871   Cond. No.                     6.67e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
lm_results.predict(X_test)
# Out:
# Date
# 2020-12-07    41.886548
# 2020-12-08    41.131574
# 2020-12-09    42.025230
# 2020-12-10    42.971196
# 2020-12-11    43.652961
# 2020-12-14    44.230280
# 2020-12-15    42.716464
# 2020-12-16    42.586416
# 2020-12-17    43.276017
# 2020-12-18    42.815098
# 2020-12-21    42.539493
# 2020-12-22    42.274626
# 2020-12-23    40.632430
# 2020-12-24    40.306407
# 2020-12-28    40.921309
# 2020-12-29    40.785326
# 2020-12-30    40.449101
# 2020-12-31    41.085178
# 2021-01-04    41.007713
# 2021-01-05    41.659329
# 2021-01-06    42.891895
# 2021-01-07    44.275017
# 2021-01-08    43.785512
# 2021-01-11    44.527271
# 2021-01-12    46.224340
# 2021-01-13    47.214296
# 2021-01-14    47.221389
# 2021-01-15    49.296488
# 2021-01-19    47.734685
# 2021-01-20    48.753841
# 2021-01-21    48.928015
# 2021-01-22    47.481921
# 2021-01-25    46.726635
# 2021-01-26    46.013989
# 2021-01-27    45.634085
# 2021-01-28    45.050796
# 2021-01-29    45.047576
# 2021-02-01    44.665839
# 2021-02-02    44.360826
# 2021-02-03    45.117044
# 2021-02-04    46.789529
# 2021-02-05    47.489933
# 2021-02-08    49.301431
# 2021-02-09    50.805893
# 2021-02-10    49.542891
# 2021-02-11    49.770208
# 2021-02-12    48.446024
# 2021-02-16    49.989358
# 2021-02-17    51.323276
# 2021-02-18    51.795829
# 2021-02-19    51.162242
# 2021-02-22    51.567837
# 2021-02-23    52.681364
# 2021-02-24    53.290963
# 2021-02-25    55.129154
# dtype: float64

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
r2_score(y_test, lm_results.predict(X_test))
# Out:
# 0.8856890673227762

# %%
mean_squared_error(y_test, lm_results.predict(X_test))**.5 #RMSE
# Out:
# 1.4382874251765394

# %%
def plot_model():
    plt.figure(figsize=(20,10))
    plt.plot(y_train.index, y_train.values, color='blue')
    plt.plot(y_test.index, y_test.values, color='orange') #actual
    plt.plot(lm_results.predict(X_test), color='green') #predicted
    plt.title(label='Forecasting Exxon Stock Prices', fontsize=24)
    plt.xlabel('Year-Month', size=20)
    plt.ylabel('USD($)', size=20)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.legend(('Training Data', 'Actual', 'Predicted'), fontsize=20);
#plt.savefig('Exxon_model_1.png', dpi=200, bbox_inches='tight');
plot_model()

# %%
allfeats
# Out:
#             Exxon_close_price  Daily News Sentiment_INT  \
# Date
# 2020-01-14              69.20                      0.00
# 2020-01-15              69.09                      0.00
# 2020-01-16              68.82                      0.00
# 2020-01-17              68.56                      0.00
# 2020-01-21              67.58                      0.00
# ...                       ...                       ...
# 2021-02-19              52.37                      0.00
# 2021-02-22              54.30                      0.00
# 2021-02-23              55.05                     -0.27
# 2021-02-24              56.70                     -0.10
# 2021-02-25              55.76                      0.00
#
#             Daily News Sentiment_NA  Value_ger_walk  Value_ger_drive  \
# Date
# 2020-01-14                     0.00      103.183824       100.824118
# 2020-01-15                     0.00      106.456471       102.264706
# 2020-01-16                    -0.50      109.984118       104.645882
# 2020-01-17                     0.10      123.211176       114.010294
# 2020-01-21                     0.00      102.055588       101.977941
# ...                             ...             ...              ...
# 2021-02-19                     0.00       89.950000        83.230000
# 2021-02-22                     0.00       93.116471        83.700000
# 2021-02-23                    -0.50       97.873235        84.882647
# 2021-02-24                    -0.50      101.482353        87.262647
# 2021-02-25                     0.07      100.442353        87.460588
#
#             Value_ger_trans  Value_ind_walk  Value_ind_drive  Value_rus_walk  \
# Date
# 2020-01-14       100.482778       98.036667        97.018333        103.6425
# 2020-01-15        99.780000      100.060000        96.381667        102.9575
# 2020-01-16       100.437778      101.966667       101.233333        108.3575
# 2020-01-17       108.340000      110.888333       115.590000        110.8375
# 2020-01-21       101.070000      109.870000       105.405000        106.6050
# ...                     ...             ...              ...             ...
# 2021-02-19       124.555000      154.333333       135.678333        109.9850
# 2021-02-22       137.328889      140.238333       119.536667         99.1550
# 2021-02-23       135.176111      142.736667       123.536667         87.9200
# 2021-02-24       136.272222      144.465000       126.061667         97.5275
# 2021-02-25       133.856111      138.656667       119.348333        115.1050
#
#             Value_rus_drive  Value_us_walk  Value_us_drive  Value_us_trans  \
# Date
# 2020-01-14         100.5600     101.940784      103.007547       99.727907
# 2020-01-15         101.9925     101.752353      104.364528       98.963256
# 2020-01-16         104.2175     102.251373      107.985849       99.501860
# 2020-01-17         108.7100     121.800784      122.748868      105.785814
# 2020-01-21         106.6375      99.581765      102.947170      101.203488
# ...                     ...            ...             ...             ...
# 2021-02-19         104.6175     139.798039      124.570566       63.199302
# 2021-02-22          87.3925     114.762353      107.692453       61.523953
# 2021-02-23          85.9750     123.046667      113.270755       62.286279
# 2021-02-24         100.7775     127.957451      117.192264       63.974884
# 2021-02-25         109.7300     131.530588      121.559245       64.381163
#
#             Value_jap_walk  Value_jap_drive  Value_jap_trans  lag_1
# Date
# 2020-01-14      100.745745        99.272340       100.258511  69.80
# 2020-01-15      104.023191       100.096596       101.187447  69.20
# 2020-01-16      114.933830       104.993617       108.546383  69.09
# 2020-01-17      152.478723       130.354468       133.495532  68.82
# 2020-01-21      107.866596       101.040638       102.690000  68.56
# ...                    ...              ...              ...    ...
# 2021-02-19      137.848085       138.339787       116.128085  52.02
# 2021-02-22      134.500426       133.183617       111.638085  52.37
# 2021-02-23      132.853617       119.534894       105.554043  54.30
# 2021-02-24      143.045957       121.992553       108.229362  55.05
# 2021-02-25      125.468723       117.577872       103.360426  56.70
#
# [274 rows x 17 columns]
