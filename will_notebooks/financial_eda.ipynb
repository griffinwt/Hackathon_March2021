# %%
import pandas as pd

# %%
jodi_demand = pd.read_excel('../data/Energy_Oil_Gas/JODI_oil_demand.xlsx')

# %%
jodi_demand.head()
# Out:
#    Value        Date               Sub-Sector Super Region  \
# 0  14.74  2016-05-01  JODI OIL-WORLD DATABASE  GLOBAL DATA
# 1  14.83  2017-04-01  JODI OIL-WORLD DATABASE  GLOBAL DATA
# 2  15.53  2015-06-01  JODI OIL-WORLD DATABASE  GLOBAL DATA
# 3  14.48  2015-12-01  JODI OIL-WORLD DATABASE  GLOBAL DATA
# 4  14.36  2014-07-01  JODI OIL-WORLD DATABASE  GLOBAL DATA
#
#        Energy Product Flow Breakdown Time Level            Country  \
# 0  TOTAL OIL PRODUCTS         DEMAND    MONTHLY  BRUNEI DARUSSALAM
# 1  TOTAL OIL PRODUCTS         DEMAND    MONTHLY  BRUNEI DARUSSALAM
# 2  TOTAL OIL PRODUCTS         DEMAND    MONTHLY  BRUNEI DARUSSALAM
# 3  TOTAL OIL PRODUCTS         DEMAND    MONTHLY  BRUNEI DARUSSALAM
# 4  TOTAL OIL PRODUCTS         DEMAND    MONTHLY  BRUNEI DARUSSALAM
#
#               Unit of Measurement                                      Source
# 0  THOUSAND BARRELS PER DAY(KB-D)  JOINT ORGANISATIONS DATA INITIATIVE - JODI
# ...

# %%
jodi_demand['Country'].value_counts()
# Out:
# SAUDI ARABIA         223
# NORWAY               223
# SWITZERLAND          223
# HONG KONG            223
# SLOVAKIA             223
#                     ...
# GEORGIA               43
# GRENADA               24
# EQUATORIAL GUINEA     18
# KAZAKHSTAN             2
# TAJIKISTAN             1
# Name: Country, Length: 100, dtype: int64

# %%
#data is broken down monthly - is this useful?

# %%
jodi_flow = pd.read_excel('../data/Energy_Oil_Gas/JODI_US_product_flow_breakdown.xlsx')

# %%
jodi_flow.head()
# Out:
#     Value        Date               Sub-Sector Super Region Energy Product  \
# 0  7471.0  2016-05-01  JODI OIL-WORLD DATABASE  GLOBAL DATA          TOTAL
# 1  7458.0  2017-04-01  JODI OIL-WORLD DATABASE  GLOBAL DATA          TOTAL
# 2  7480.0  2015-06-01  JODI OIL-WORLD DATABASE  GLOBAL DATA          TOTAL
# 3  7480.0  2015-12-01  JODI OIL-WORLD DATABASE  GLOBAL DATA          TOTAL
# 4  7447.0  2009-02-01  JODI OIL-WORLD DATABASE  GLOBAL DATA          TOTAL
#
#    Flow Breakdown Time Level        Country            Unit of Measurement  \
# 0  CLOSING STOCKS    MONTHLY  UNITED STATES  CONVERSION FACT BARRELS-KTONS
# 1  CLOSING STOCKS    MONTHLY  UNITED STATES  CONVERSION FACT BARRELS-KTONS
# 2  CLOSING STOCKS    MONTHLY  UNITED STATES  CONVERSION FACT BARRELS-KTONS
# 3  CLOSING STOCKS    MONTHLY  UNITED STATES  CONVERSION FACT BARRELS-KTONS
# 4  CLOSING STOCKS    MONTHLY  UNITED STATES  CONVERSION FACT BARRELS-KTONS
#
#                                        Source
# ...

# %%
jodi_flow.shape
# Out:
# (17760, 10)

# %%
#also monthly...

# %%
commodity = pd.read_excel('../data/Financial_Market/commodity_prices.xlsx')

# %%
commodity.head()
# Out:
#       Value        Date        Sub-Sector Super Region  \
# 0  393834.0  2020-08-07  COMMODITY PRICES  GLOBAL DATA
# 1  865736.0  2018-03-07  COMMODITY PRICES  GLOBAL DATA
# 2  345299.0  2021-01-25  COMMODITY PRICES  GLOBAL DATA
# 3  353417.0  2020-08-06  COMMODITY PRICES  GLOBAL DATA
# 4  626407.0  2018-03-06  COMMODITY PRICES  GLOBAL DATA
#
#     Commodity And Exchange Frequency              Source Indicator
# 0  NYMEX CRUDE OIL FUTURES     DAILY  COMMODITY EXCHANGE    VOLUME
# 1  NYMEX CRUDE OIL FUTURES     DAILY  COMMODITY EXCHANGE    VOLUME
# 2  NYMEX CRUDE OIL FUTURES     DAILY  COMMODITY EXCHANGE    VOLUME
# 3  NYMEX CRUDE OIL FUTURES     DAILY  COMMODITY EXCHANGE    VOLUME
# 4  NYMEX CRUDE OIL FUTURES     DAILY  COMMODITY EXCHANGE    VOLUME

# %%
commodity['Commodity And Exchange'].value_counts()
# Out:
# NYMEX CRUDE OIL FUTURES                 8000
# ICE BRENT CRUDE OIL FUTURES             7000
# WTI CRUDE OIL (DOLLARS PER BARREL)      1000
# BRENT CRUDE OIL (DOLLARS PER BARREL)    1000
# Name: Commodity And Exchange, dtype: int64

# %%
commodity['Indicator'].value_counts()
# Out:
# PRICE IN USD                  2000
# LOW                           2000
# HIGH                          2000
# SETTLE                        2000
# VOLUME                        2000
# CHANGE                        2000
# OPEN                          2000
# PREVIOUS DAY OPEN INTEREST    1000
# PREV# DAY OPEN INTEREST       1000
# LAST                          1000
# Name: Indicator, dtype: int64

# %%
commodity['Date'] = pd.to_datetime(commodity['Date'])

# %%
com = pd.DataFrame(commodity.groupby('Date')['Value'].count())

# %%
com #preview
# Out:
#             Value
# Date
# 2016-11-22      1
# 2016-11-23      1
# 2016-11-24      1
# 2016-11-25      1
# 2016-11-28      1
# ...           ...
# 2021-02-22     16
# 2021-02-23     14
# 2021-02-24     14
# 2021-02-25     14
# 2021-02-26     14
#
# [1101 rows x 1 columns]

# %%
sec_fil = pd.read_excel('../data/Financial_Market/SEC_filings_E&P.xlsx')

# %%
sec_fil
# Out:
#              Value        Date   Super Region Ticker Time Level Unit  \
# 0    -2.010000e+08  2014-12-31  UNITED STATES    MRO    QUARTER  USD
# 1    -2.380000e+08  2016-06-30  UNITED STATES    MRO    QUARTER  USD
# 2    -2.400000e+07  2016-12-31  UNITED STATES    MRO    QUARTER  USD
# 3    -4.200000e+08  2015-03-31  UNITED STATES    MRO    QUARTER  USD
# 4     5.110000e+08  2014-06-30  UNITED STATES    MRO    QUARTER  USD
# ...            ...         ...            ...    ...        ...  ...
# 3055 -5.220000e+05  2009-06-30  UNITED STATES    PXD    QUARTER  USD
# 3056  1.535200e+07  2010-03-31  UNITED STATES    PXD    QUARTER  USD
# 3057  7.000000e-02  2009-12-31  UNITED STATES    EOG    QUARTER  USD
# 3058  7.000000e-02  2009-09-30  UNITED STATES    EOG    QUARTER  USD
# 3059  7.000000e-02  2009-06-30  UNITED STATES    EOG    QUARTER  USD
#
#                    Source                 Exchange           Sub-Sector  \
# ...

# %%
sec_int = pd.read_excel('../data/Financial_Market/SEC_filings_Integrated.xlsx')
sec_int.head()
# Out:
#          Value        Date   Super Region Ticker Time Level Unit  \
# 0   68000000.0  2014-12-31  UNITED STATES    XOM    QUARTER  USD
# 1   75000000.0  2016-06-30  UNITED STATES    XOM    QUARTER  USD
# 2  195000000.0  2016-12-31  UNITED STATES    XOM    QUARTER  USD
# 3   88000000.0  2015-03-31  UNITED STATES    XOM    QUARTER  USD
# 4   64000000.0  2014-06-30  UNITED STATES    XOM    QUARTER  USD
#
#                 Source                 Exchange           Sub-Sector  \
# 0  COMPANY SEC FILINGS  NEW YORK STOCK EXCHANGE  FINANCIAL STATEMENT
# 1  COMPANY SEC FILINGS  NEW YORK STOCK EXCHANGE  FINANCIAL STATEMENT
# 2  COMPANY SEC FILINGS  NEW YORK STOCK EXCHANGE  FINANCIAL STATEMENT
# 3  COMPANY SEC FILINGS  NEW YORK STOCK EXCHANGE  FINANCIAL STATEMENT
# 4  COMPANY SEC FILINGS  NEW YORK STOCK EXCHANGE  FINANCIAL STATEMENT
#
#               Company Name        Industry Level 2 Industry Level 1  \
# 0  EXXON MOBIL CORPORATION  OIL & GAS - INTEGRATED           ENERGY
# ...

# %%
sec_ref = pd.read_excel('../data/Financial_Market/SEC_filings_ref&mark_o&g_services.xlsx')
sec_ref.head()
# Out:
#           Value        Date   Super Region Ticker Time Level Unit  \
# 0  1.674000e+09  2014-12-31  UNITED STATES    PSX    QUARTER  USD
# 1  1.089000e+09  2016-06-30  UNITED STATES    PSX    QUARTER  USD
# 2  4.560000e+08  2016-12-31  UNITED STATES    PSX    QUARTER  USD
# 3  1.654000e+09  2015-03-31  UNITED STATES    PSX    QUARTER  USD
# 4  1.687000e+09  2014-06-30  UNITED STATES    PSX    QUARTER  USD
#
#                 Source                 Exchange           Sub-Sector  \
# 0  COMPANY SEC FILINGS  NEW YORK STOCK EXCHANGE  FINANCIAL STATEMENT
# 1  COMPANY SEC FILINGS  NEW YORK STOCK EXCHANGE  FINANCIAL STATEMENT
# 2  COMPANY SEC FILINGS  NEW YORK STOCK EXCHANGE  FINANCIAL STATEMENT
# 3  COMPANY SEC FILINGS  NEW YORK STOCK EXCHANGE  FINANCIAL STATEMENT
# 4  COMPANY SEC FILINGS  NEW YORK STOCK EXCHANGE  FINANCIAL STATEMENT
#
#   Company Name                  Industry Level 2 Industry Level 1  \
# 0  PHILLIPS 66  OIL & GAS - REFINING & MARKETING           ENERGY
# ...
