# %%
import pandas as pd

# %%
#using the non-mobility df (includes more rows of data)
df = pd.read_csv('../targets_wout_mobility2.csv')

# %%
df
# Out:
#            date  Value_PHILLIPS 66  Value_BP P.L.C.  \
# 0    2017-03-21              78.60            34.24
# 1    2017-03-22              78.83            33.99
# 2    2017-03-23              78.48            34.06
# 3    2017-03-24              77.27            33.78
# 4    2017-03-27              77.25            33.75
# ..          ...                ...              ...
# 980  2021-02-19              82.31            22.87
# 981  2021-02-22              83.96            23.63
# 982  2021-02-23              85.53            24.23
# 983  2021-02-24              87.25            25.30
# 984  2021-02-25              84.64            25.59
#
#      Value_VALERO ENERGY CORPORATION  Value_CHEVRON CORPORATION  \
# 0                              67.15                     108.04
# 1                              67.57                     108.39
# 2                              67.10                     107.87
# 3                              65.78                     107.99
# ...

# %%
df.set_index(pd.to_datetime(df['date']), inplace=True)
df.drop(columns='date', inplace=True)
df.sort_index(inplace=True)
df #review changes
# Out:
#             Value_PHILLIPS 66  Value_BP P.L.C.  \
# date
# 2017-03-21              78.60            34.24
# 2017-03-22              78.83            33.99
# 2017-03-23              78.48            34.06
# 2017-03-24              77.27            33.78
# 2017-03-27              77.25            33.75
# ...                       ...              ...
# 2021-02-19              82.31            22.87
# 2021-02-22              83.96            23.63
# 2021-02-23              85.53            24.23
# 2021-02-24              87.25            25.30
# 2021-02-25              84.64            25.59
#
#             Value_VALERO ENERGY CORPORATION  Value_CHEVRON CORPORATION  \
# date
# 2017-03-21                            67.15                     108.04
# 2017-03-22                            67.57                     108.39
# 2017-03-23                            67.10                     107.87
# 2017-03-24                            65.78                     107.99
# ...

# %%
df.isnull().sum()
# Out:
# Value_PHILLIPS 66                            0
# Value_BP P.L.C.                              0
# Value_VALERO ENERGY CORPORATION              0
# Value_CHEVRON CORPORATION                    0
# Value_OCCIDENTAL PETROLEUM CORPORATION       0
# Value_MARATHON OIL CORPORATION               0
# Value_PIONEER NATURAL RESOURCES COMPANY      0
# Value_CONOCOPHILLIPS                         0
# Value_EXXON MOBIL CORPORATION                0
# Value_MARATHON PETROLEUM CORPORATION         0
# d_f_chevron                                  0
# d_f_drilling                                 0
# d_f_exxon                                    0
# d_f_fossil_fuel                              0
# d_f_marathon_oil                             0
# d_f_occidental_petroleum                     0
# d_f_oil                                      0
# d_f_oilfield                                 0
# d_f_phillips_66                              0
# d_f_pipeline                               464
# ...

# %%
df[df['futures_prev_day_open_interest'].isnull()]
# Out:
#             Value_PHILLIPS 66  Value_BP P.L.C.  \
# date
# 2017-07-03              83.34            35.02
# 2018-11-23              89.00            39.89
# 2018-12-24              78.50            36.65
# 2018-12-31              86.15            37.92
# 2019-07-05              96.80            41.03
# 2019-11-11             118.41            39.15
# 2020-02-29              74.86            31.29
# 2020-03-01              74.86            31.29
# 2020-03-07              69.30            31.25
# 2020-03-08              69.30            31.25
# 2020-03-21              48.35            17.39
# 2020-03-22              48.35            17.39
# 2020-03-29              52.32            22.35
# 2020-04-04              51.62            24.72
# 2020-04-05              51.62            24.72
#
#             Value_VALERO ENERGY CORPORATION  Value_CHEVRON CORPORATION  \
# date
# 2017-07-03                            68.02                     106.30
# ...

# %% [markdown]
# Solutions to null values:
# - the pipeline (direct, financial news source) and hurricane_storm (indirect, financial) will be dropped; these are roughly 50% and close to 90% of all rows and imputing zeroes for that much data raises a legitimate question of how useful they will be; there is also consolation in the fact that both keywords will still make it into the model by way of the global news sources.
# - The futures and per barrel pricing nans will be dropped - it looks like they are all the same dates, several of which appear to be observed holidays (7/3/17, 11/23/18, 12/24/18, 12/31/18, 7/5/19); 15 rows aren't too big of a proportion of the data that I think dropping them should significantly affect the model

# %%
#drop entire column:
df.drop(columns=['d_f_pipeline', 'i_f_hurricane_storm'], inplace=True)

#drop remaining (45) null values
df.dropna(inplace=True)

# %%
df.isnull().sum().sum() #verify
# Out:
# 0

# %%
df.shape
# Out:
# (970, 52)

# %% [markdown]
# The next step is to lag everything (except prev day interest which is already a day behind) so that we don't have future data leaking into our predictions.

# %%
tolag = list(df.drop(columns='futures_prev_day_open_interest').columns)
len(tolag) #should be 1 less than all columns = 51
# Out:
# 51

# %%
#loop through all features and create a column that is 1 day lagged for each
for var in tolag:
    df[f'lag_{var}'] = df[var].shift()
df #preview changes
# Out:
#             Value_PHILLIPS 66  Value_BP P.L.C.  \
# date
# 2017-03-21              78.60            34.24
# 2017-03-22              78.83            33.99
# 2017-03-23              78.48            34.06
# 2017-03-24              77.27            33.78
# 2017-03-27              77.25            33.75
# ...                       ...              ...
# 2021-02-19              82.31            22.87
# 2021-02-22              83.96            23.63
# 2021-02-23              85.53            24.23
# 2021-02-24              87.25            25.30
# 2021-02-25              84.64            25.59
#
#             Value_VALERO ENERGY CORPORATION  Value_CHEVRON CORPORATION  \
# date
# 2017-03-21                            67.15                     108.04
# 2017-03-22                            67.57                     108.39
# 2017-03-23                            67.10                     107.87
# 2017-03-24                            65.78                     107.99
# ...

# %%
tolag = tolag[10:] #remake the list to remove the target variables

# %%
df.drop(columns=tolag, inplace=True) #drop sameday features now that we have the lagged features

# %%
df.shape #confirm - should be 52 feats + 10 lagged closing prices
# Out:
# (970, 62)

# %%
#df.to_csv('../lagged_wout_mobility.csv') #save for future use

# %%
original = df.copy() #save a clean copy of the original in case of future critical error

# %%
targets = list(df.columns)[:10] #first 10 are the closing prices i.e. the y or target value
targets #confirm
# Out:
# ['Value_PHILLIPS 66',
#  'Value_BP P.L.C.',
#  'Value_VALERO ENERGY CORPORATION',
#  'Value_CHEVRON CORPORATION',
#  'Value_OCCIDENTAL PETROLEUM CORPORATION',
#  'Value_MARATHON OIL CORPORATION',
#  'Value_PIONEER NATURAL RESOURCES COMPANY',
#  'Value_CONOCOPHILLIPS',
#  'Value_EXXON MOBIL CORPORATION',
#  'Value_MARATHON PETROLEUM CORPORATION']

# %%
#preview of prices of time (actual)
import matplotlib.pyplot as plt
def plot_series(df, cols, title='Title', xlab=None, ylab=None): #from GA DSI Lesson 10.2 taught by Dan Wilhelm
    plt.figure(figsize=(35,23))
    for col in cols:
        plt.plot(df[col])
    plt.title(title, fontsize=30)
    plt.xlabel(xlab, fontsize=25)
    plt.ylabel(ylab, fontsize=25)
    plt.xticks(fontsize=20)
    #plt.xticks(np.arange(0,len(df)+1, 96),fontsize=18)
   # plt.set_xticks(np.arrange(0,len(df)+1, 48))
    plt.yticks(fontsize=20)

plot_series(df.dropna(), targets, title='Daily Closing Price - Energy Stocks',
           xlab='Year-Month', ylab='USD($)')
plt.legend(targets, fontsize=22);
#plt.savefig('../images/all_closing_wout_mobility.png', dpi=200, bbox_inches='tight');

# %%
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.metrics import r2_score, mean_squared_error

# %%
df.dropna(inplace=True) #drop first row of nulls created by shift

# %%
#cycle through all 10 targets and model all of them, saving each collection of predictions
pred_list = {}
train_list = {}
test_list = {}
scores = {}
coefs = {}
for target in targets:
    X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=targets), #drop all target columns
                                                   df[target], #target is selected as y
                                                   test_size=.2, #80%/20% train/test split
                                                   shuffle=False) #predict most recent values
    X_train = sm.add_constant(X_train)
    X_test = sm.add_constant(X_test) #add intercepts
    lm = sm.OLS(y_train, X_train)
    lm_results = lm.fit()
    preds = lm_results.predict(X_test)
    train_list[target] = y_train #update dictionary with y_train
    test_list[target] = y_test #update dictionary with y_test
    pred_list[target] = preds #update dictionary with preds
    coefs[target] = lm_results.params #update dictionary with coefficient values
    scores[target] = mean_squared_error(y_test, lm_results.predict(X_test))**.5 #update dictionary with RMSE score
final_preds = pd.DataFrame(pred_list) #turn dictionary of lists into dataframe of preds
training = pd.DataFrame(train_list)
testing = pd.DataFrame(test_list)
coefs = pd.DataFrame(coefs)

# %%
def plot_preds(ytraindf, ytestdf, pred_df, title='Title', xlab=None, ylab=None):
    plt.figure(figsize=(35,23))
    for col in ytraindf.columns:
        plt.plot(ytraindf[col], linewidth=3) #plot each ytrain
    for col in ytestdf.columns:
        plt.plot(ytestdf[col], color='black', linewidth=2) #plot each ytest
    for col in pred_df.columns:
        plt.plot(pred_df[col], color='magenta', linewidth=2) #plot the preds
    plt.title(title, fontsize=30)
    plt.xlabel(xlab, fontsize=25)
    plt.ylabel(ylab, fontsize=25)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)

plot_preds(training, testing, final_preds, title='Predicting Daily Closing Price - Energy Stocks',
           xlab='Year-Month', ylab='USD($)')
plt.legend(final_preds.columns, fontsize=22);
plt.savefig('../images/wout_mobility_preds_1.png', dpi=200, bbox_inches='tight')

# %%
pd.DataFrame(scores, index=('RMSE',)).T
# Out:
#                                              RMSE
# Value_PHILLIPS 66                        2.279662
# Value_BP P.L.C.                          0.657330
# Value_VALERO ENERGY CORPORATION          2.261641
# Value_CHEVRON CORPORATION                2.936090
# Value_OCCIDENTAL PETROLEUM CORPORATION   1.332773
# Value_MARATHON OIL CORPORATION           0.495249
# Value_PIONEER NATURAL RESOURCES COMPANY  4.467428
# Value_CONOCOPHILLIPS                     1.455618
# Value_EXXON MOBIL CORPORATION            1.532155
# Value_MARATHON PETROLEUM CORPORATION     1.391904

# %% [markdown]
# Need to investigate the coefficients - ideally by looping through and finding which features were most significant for each target.

# %%
#coefs['Value_PHILLIPS 66'].abs().sort_values(ascending = False) #top 5 larges (abs values) coefs

# %%
imp = list(dict(coefs['Value_PHILLIPS 66'].abs().sort_values(ascending = False)[:5]).keys())
imp
# Out:
# ['lag_d_f_marathon_oil',
#  'lag_d_f_phillips_66',
#  'lag_d_f_occidental_petroleum',
#  'lag_Value_PHILLIPS 66',
#  'lag_i_f_carbon_footprint']

# %%
imp_dict = dict(coefs['Value_PHILLIPS 66'])

# %%
l1 = [] #empty list
d1 = {} #empty dictionary
for n in range(len(imp)):
    d1[imp[n]] = imp_dict[imp[n]]
l1.append(d1)
pd.DataFrame(l1, index=('Phillips 66',))
# Out:
#              lag_d_f_marathon_oil  lag_d_f_phillips_66  \
# Phillips 66              2.745156            -2.257565
#
#              lag_d_f_occidental_petroleum  lag_Value_PHILLIPS 66  \
# Phillips 66                      -1.36716               1.007122
#
#              lag_i_f_carbon_footprint
# Phillips 66                 -0.991558

# %%
l1 = [] #empty list
recurrance = [] #second list for recording all 50 top 5 features
for feature in coefs.columns:
    l2 = [] #empty list
    imp = list(dict(coefs[feature].abs().sort_values(ascending = False)[:5]).keys()) #top 5 biggest (abs value) coefs
    imp_dict = dict(coefs[feature]) #dictionary of all coefs for particular target
    for rec in imp:
        recurrance.append(rec) #add each feature's top 5 coefs to master list
    for n in range(len(imp)):
        l2.append(f'{imp[n]}: {round(imp_dict[imp[n]],2)}')
    l1.append(l2) #add list of top 5 to list
print(pd.DataFrame(l1, index=coefs.columns, columns=['First', 'Second', 'Third', 'Fourth', 'Fifth']).to_markdown())
# Out:
# |                                         | First                                            | Second                                   | Third                                   | Fourth                                         | Fifth                              |
# |:----------------------------------------|:-------------------------------------------------|:-----------------------------------------|:----------------------------------------|:-----------------------------------------------|:-----------------------------------|
# | Value_PHILLIPS 66                       | lag_d_f_marathon_oil: 2.75                       | lag_d_f_phillips_66: -2.26               | lag_d_f_occidental_petroleum: -1.37     | lag_Value_PHILLIPS 66: 1.01                    | lag_i_f_carbon_footprint: -0.99    |
# ...

# %%
print(pd.DataFrame(recurrance, columns=['Feature_count'])['Feature_count'].value_counts().to_markdown())
# Out:
# |                                            |   Feature_count |
# |:-------------------------------------------|----------------:|
# | lag_d_f_oil                                |               8 |
# | lag_d_f_marathon_oil                       |               7 |
# | lag_d_f_phillips_66                        |               5 |
# | const                                      |               5 |
# | lag_i_f_carbon_footprint                   |               4 |
# | lag_d_f_valero                             |               3 |
# | lag_d_f_occidental_petroleum               |               3 |
# | lag_d_f_fossil_fuel                        |               3 |
# | lag_Value_CONOCOPHILLIPS                   |               1 |
# | lag_Value_EXXON MOBIL CORPORATION          |               1 |
# | lag_Value_OCCIDENTAL PETROLEUM CORPORATION |               1 |
# | lag_i_g_hurricane_storm                    |               1 |
# ...

# %%
df.columns
# Out:
# Index(['Value_PHILLIPS 66', 'Value_BP P.L.C.',
#        'Value_VALERO ENERGY CORPORATION', 'Value_CHEVRON CORPORATION',
#        'Value_OCCIDENTAL PETROLEUM CORPORATION',
#        'Value_MARATHON OIL CORPORATION',
#        'Value_PIONEER NATURAL RESOURCES COMPANY', 'Value_CONOCOPHILLIPS',
#        'Value_EXXON MOBIL CORPORATION', 'Value_MARATHON PETROLEUM CORPORATION',
#        'futures_prev_day_open_interest', 'lag_Value_PHILLIPS 66',
#        'lag_Value_BP P.L.C.', 'lag_Value_VALERO ENERGY CORPORATION',
#        'lag_Value_CHEVRON CORPORATION',
#        'lag_Value_OCCIDENTAL PETROLEUM CORPORATION',
#        'lag_Value_MARATHON OIL CORPORATION',
#        'lag_Value_PIONEER NATURAL RESOURCES COMPANY',
#        'lag_Value_CONOCOPHILLIPS', 'lag_Value_EXXON MOBIL CORPORATION',
#        'lag_Value_MARATHON PETROLEUM CORPORATION', 'lag_d_f_chevron',
#        'lag_d_f_drilling', 'lag_d_f_exxon', 'lag_d_f_fossil_fuel',
# ...

# %%
selectafeat = ['direct_g', 'direct_f','indirect_g', 'indirect_f', 'financial']

targets = ['Value_PHILLIPS 66', 'Value_BP P.L.C.',
       'Value_VALERO ENERGY CORPORATION', 'Value_CHEVRON CORPORATION',
       'Value_OCCIDENTAL PETROLEUM CORPORATION',
       'Value_MARATHON OIL CORPORATION',
       'Value_PIONEER NATURAL RESOURCES COMPANY', 'Value_CONOCOPHILLIPS',
       'Value_EXXON MOBIL CORPORATION', 'Value_MARATHON PETROLEUM CORPORATION']

lagged_targets = ['lag_Value_PHILLIPS 66', #target value from the previous day
       'lag_Value_BP P.L.C.', 'lag_Value_VALERO ENERGY CORPORATION',
       'lag_Value_CHEVRON CORPORATION',
       'lag_Value_OCCIDENTAL PETROLEUM CORPORATION',
       'lag_Value_MARATHON OIL CORPORATION',
       'lag_Value_PIONEER NATURAL RESOURCES COMPANY',
       'lag_Value_CONOCOPHILLIPS', 'lag_Value_EXXON MOBIL CORPORATION',
       'lag_Value_MARATHON PETROLEUM CORPORATION']

#lists of selectable feature combinations that dictionary refers to

direct_g = ['lag_d_g_chevron', 'lag_d_g_drilling', 'lag_d_g_exxon',
       'lag_d_g_fossil_fuel', 'lag_d_g_oil', 'lag_d_g_oilfield',
       'lag_d_g_pipeline', 'lag_d_g_valero']

direct_f = ['lag_d_f_chevron',
       'lag_d_f_drilling', 'lag_d_f_exxon', 'lag_d_f_fossil_fuel',
       'lag_d_f_marathon_oil', 'lag_d_f_occidental_petroleum', 'lag_d_f_oil',
       'lag_d_f_oilfield', 'lag_d_f_phillips_66', 'lag_d_f_valero']

indirect_g = ['lag_i_g_airline', 'lag_i_g_carbon_footprint', 'lag_i_g_emissions',
       'lag_i_g_epa', 'lag_i_g_greenhouse', 'lag_i_g_hurricane_storm',
       'lag_i_g_pollution', 'lag_i_g_sanction', 'lag_i_g_solar',
       'lag_i_g_turbine', 'lag_i_g_vacation']

indirect_f = ['lag_i_f_airline',
       'lag_i_f_carbon_footprint', 'lag_i_f_emissions', 'lag_i_f_epa',
       'lag_i_f_greenhouse', 'lag_i_f_pollution', 'lag_i_f_sanction',
       'lag_i_f_solar', 'lag_i_f_turbine', 'lag_i_f_vacation']

financial = ['lag_futures_settle',
       'lag_crude_usd_per_barrel', 'futures_prev_day_open_interest']

#dictionary to lookup combinations of features
selection = {
    'direct_g':direct_g,
    'direct_f':direct_f,
    'indirect_g':direct_g,
    'indirect_f':indirect_f,
    'financial':financial
}

# %%
l1 = targets + lagged_targets + financial + indirect_f + indirect_g + direct_f + direct_g

len(df.columns) == len(l1)
# Out:
# True

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
#df.to_csv('../app_dataset.csv') #saving for use in app
